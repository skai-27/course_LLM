# %% [markdown]
# # Multi Agents - 자율 연구 에이전트
# LangGraph를 활용하여 동적 워크플로우, 루프/재귀, Human-in-the-loop 패턴을 구현하는 자율 연구 시스템을 만듭니다.

# %% [markdown]
# ## 구성
# 1. **계획 에이전트**: 연구 주제 분석 및 계획 수립
# 2. **검색 에이전트**: 정보 수집 및 자료 검색
# 3. **분석 에이전트**: 수집된 데이터 분석
# 4. **검증 에이전트**: 정보의 신뢰성과 완성도 검증
# 5. **조정 에이전트**: 추가 조사 필요 여부 판단 및 워크플로우 제어
# 6. **보고서 에이전트**: 최종 연구 보고서 작성

# %% [markdown]
# ## 학습 목표
# - 동적 워크플로우 (Dynamic Workflow): 실행 중 경로 변경
# - 루프와 재귀 (Loop & Recursion): 조건에 따라 반복 실행
# - Human-in-the-loop (HITL): 중요한 결정에 사용자 개입

# %% [markdown]
# ## 1. LLM

# %% [markdown]
# ### API 키 설정
# - [OpenAI API 키](https://platform.openai.com/api-keys)
# - [Tavily API 키](https://tavily.com/) - 실제 웹 검색 기능 사용 (선택사항)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

# API 키 확인
openai_key = os.getenv("OPENAI_API_KEY")
tavily_key = os.getenv("TAVILY_API_KEY")

if openai_key:
    print("OpenAI API 키가 설정되었습니다. (GPT 모델 사용)")
else:
    print("OpenAI API 키가 없습니다.")

if tavily_key:
    print("Tavily API 키가 설정되었습니다. (웹 검색 사용)")
else:
    print("Tavily API 키가 없습니다. (검색 기능이 시뮬레이션 모드로 작동합니다)")
# Out:
# OpenAI API 키가 설정되었습니다. (GPT 모델 사용)
# Tavily API 키가 설정되었습니다. (웹 검색 사용)

# %% [markdown]
# ### LLM 초기화

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-5-nano",
    reasoning_effort="high",        # 논리성 강화
)

# %% [markdown]
# ### Tavily 검색 도구 초기화 (실제 웹 검색용)

# %%
from langchain_tavily import TavilySearch

tavily_search = TavilySearch(
    max_results=3,
    topic="general",               # 또는 "news", "finance" 등
    include_answer=True,           # 답변 포함 여부
    include_raw_content=True,     # 원본 내용 포함 여부
    include_images=False,          # 이미지 포함 여부
    search_depth="advanced",          # "basic" 또는 "advanced"
    include_domains=[
        "https://www.naver.com", # 뉴스
        "https://www.weatheri.co.kr/", # 날씨 
        "https://kr.investing.com/equities/south-korea" # 주식
    ],
    exclude_domains=None            # 필요하면 제외 도메인 지정 가능
)

# %% [markdown]
# ## 2. 상태 정의 (State Management)
#
# 고급 워크플로우를 위한 복잡한 상태 구조를 정의합니다. 루프 제어, 이력 관리, 검증 상태 등을 포함합니다.

# %%
from typing import TypedDict, List, Literal, Annotated
from operator import add

class ResearchState(TypedDict):
    """
    자율 연구 시스템의 상태를 정의하는 클래스
    """
    topic: str                                      # 연구 주제
    research_plan: str                              # 연구 계획
    search_results: Annotated[List[str], add]       # 검색 결과 리스트 (누적)
    analysis_results: Annotated[List[str], add]     # 분석 결과 리스트 (누적)
    verification_status: str                        # 검증 상태 (passed/failed)
    verification_feedback: str                      # 검증 피드백
    needs_more_research: bool                       # 추가 연구 필요 여부
    iteration_count: int                            # 반복 횟수 (무한 루프 방지)
    max_iterations: int                             # 최대 반복 횟수 (주제 복잡도에 따라 동적 설정)
    human_approval: bool                            # 사용자 승인 여부
    final_report: str                               # 최종 보고서

# %% [markdown]
# ## 3. 에이전트 노드 정의

# %% [markdown]
# ### 3.1 복잡도 에이전트

# %%
from langchain_core.messages import HumanMessage, SystemMessage

def complexity_level_of_topic_agent(state: ResearchState) -> dict:
    """
    주제의 복잡도를 평가하여 최대 반복 횟수를 동적으로 설정하는 에이전트
    """
    topic = state["topic"]
    
    complexity_messages = [
        SystemMessage(content="""
            당신은 연구 주제 복잡도 평가 전문가입니다.
            주어진 주제의 복잡도를 평가하세요:

            - SIMPLE: 단순하고 명확한 주제 (예: 특정 기술 소개, 단일 개념 설명)
            - MODERATE: 중간 복잡도 주제 (예: 기술 비교, 트렌드 분석)
            - COMPLEX: 복잡한 주제 (예: 다면적 분석, 미래 예측, 철학적 논의)

            반드시 "COMPLEXITY: SIMPLE", "COMPLEXITY: MODERATE", "COMPLEXITY: COMPLEX" 중 하나로 시작하세요."""),
        HumanMessage(content=f"주제: {topic}\n\n이 주제의 복잡도를 평가하세요.")
    ]
    
    complexity_response = llm.invoke(complexity_messages)
    complexity_text = complexity_response.content
    
    # 복잡도에 따른 최대 반복 횟수 설정
    if "COMPLEXITY: SIMPLE" in complexity_text:
        max_iterations = 2
        complexity_level = "단순"
    elif "COMPLEXITY: COMPLEX" in complexity_text:
        max_iterations = 4
        complexity_level = "복잡"
    else:
        max_iterations = 3
        complexity_level = "중간"
    
    print(f"[주제의 복잡도 에이전트] 주제 복잡도: {complexity_level} (최대 {max_iterations}회 반복)")
        
    return {
        "max_iterations": max_iterations
    }

# %% [markdown]
# ### 3.2 계획 에이전트

# %%
def __planning_of_topic(state: ResearchState):
    """
    연구 주제를 분석하고 상세한 연구 계획을 수립
    """
    topic = state["topic"]

    # 재연구인 경우 피드백 반영
    feedback = state.get("verification_feedback", "")
    feedback_context = f"\n\n이전 피드백: {feedback}" if feedback else ""
    
    messages = [
        SystemMessage(content="""
            당신은 연구 계획 전문가입니다.
            주어진 주제에 대해 체계적인 연구 계획을 수립하세요:
            1. 핵심 조사 질문 정의
            2. 필요한 정보 유형 파악
            3. 검색 키워드 제안
            4. 분석 방향 제시

            간결하고 실행 가능한 계획을 작성하세요."""),
        HumanMessage(content=f"주제: {topic}{feedback_context}\n\n연구 계획을 수립하세요.")
    ]
    
    response = llm.invoke(messages)
    
    return response.content

# %%
def planning_agent(state: ResearchState) -> dict:
    """
    연구 주제를 분석하고 상세한 연구 계획을 수립하는 에이전트
    """
    iteration_count = state.get('iteration_count', 0)
    max_iterations = state['max_iterations']
    
    plan = __planning_of_topic(state)
    
    print(f"[계획 에이전트] 연구 계획 수립 완료 (반복 {iteration_count + 1}회 / 최대 {max_iterations}회)")
    
    return {
        "research_plan": plan,
        "iteration_count": iteration_count + 1,
        "max_iterations": max_iterations
    }

# %% [markdown]
# ### 3.3 검색 에이전트 (TavilySearchResults 사용)
#
# 실제 웹 검색을 수행하는 에이전트입니다.
#
# **TavilySearchResults 사용:**
# - Tavily API 키가 있으면 실제 웹 검색 수행
# - Tavily API 키가 없으면 시뮬레이션 모드로 작동
# - API 키 발급: [Tavily](https://tavily.com/)
#
# **참고:** Tavily API 키를 설정하려면 위의 API 키 설정 셀에서 주석을 제거하고 키를 입력하세요.

# %%
def search_agent(state: ResearchState) -> dict:
    """
    연구 계획에 따라 정보를 검색하고 수집하는 에이전트
    TavilySearchResults를 사용하여 실제 웹 검색 수행
    """
    topic = state["topic"]
    iteration = state['iteration_count']
    
    # Tavily 검색이 가능한 경우 실제 웹 검색 수행
    # 검색 쿼리 생성 (주제 + 계획의 핵심 키워드)
    search_query = f"{topic}"
    
    print(f"[검색 에이전트] 웹 검색 실행: {search_query}")
    
    # 실제 웹 검색 수행
    search_results_raw = tavily_search.invoke({"query": search_query})
    
    # 검색 결과를 포맷팅
    formatted_results = []
    for i, result in enumerate(search_results_raw['results'], 1):
        url = result.get('url', 'N/A')
        content = result.get('content', 'N/A')
        formatted_results.append(f"출처 {i}: {url}\n내용: {content}")
    
    search_result_text = "\n\n".join(formatted_results)
    
    # LLM을 사용하여 검색 결과 요약 및 분석
    summary_messages = [
        SystemMessage(content="""
        당신은 정보 분석 전문가입니다.
        웹 검색 결과를 분석하여 연구 주제와 관련된 핵심 정보를 요약하세요.
        - 각 출처의 주요 내용 정리
        - 관련성 높은 정보 강조
        - 상충되는 정보가 있다면 명시"""),
        HumanMessage(content=f"""
        주제: {topic}
        
        검색 결과:
        {search_result_text}
        
        이 결과를 요약하고 분석하세요.""")
    ]
    
    summary_response = llm.invoke(summary_messages)
    
    search_result = f"""
    [실제 웹 검색 결과 - 반복 {iteration}]
    
    {summary_response.content}
    
    --- 원본 검색 결과 ---
    {search_result_text[:500]}..."""
    
    print(f"[검색 에이전트] 실제 웹 검색 완료 ({len(search_results_raw)}개 결과)")
    
    return {
        "search_results": [search_result]
    }

# %% [markdown]
# ### 3.4 분석 에이전트

# %%
def analysis_agent(state: ResearchState) -> dict:
    """
    수집된 정보를 분석하고 인사이트를 도출하는 에이전트
    """
    topic = state["topic"]
    search_results = state["search_results"]
    
    # 최신 검색 결과만 분석 (또는 전체 분석)
    recent_results = "\n\n".join(search_results[-3:])  # 최근 3개
    
    messages = [
        SystemMessage(content="""
            당신은 데이터 분석 전문가입니다.
            수집된 정보를 분석하여:
            1. 핵심 패턴과 트렌드 파악
            2. 주요 발견사항 정리
            3. 상충되는 정보 식별
            4. 추가 조사가 필요한 부분 지적

            분석적이고 비판적인 관점을 유지하세요."""),
        HumanMessage(content=f"주제: {topic}\n\n검색 결과:\n{recent_results}\n\n이 정보를 분석하세요.")
    ]
    
    response = llm.invoke(messages)
    analysis = f"[분석 결과 - 반복 {state['iteration_count']}]\n{response.content}"
    
    print(f"[분석 에이전트] 데이터 분석 완료")
    
    return {
        "analysis_results": [analysis]
    }

# %% [markdown]
# ### 3.5 검증 에이전트

# %%
def verification_agent(state: ResearchState) -> dict:
    """
    정보의 신뢰성과 완성도를 검증하는 에이전트
    """
    topic = state["topic"]
    analysis_results = state["analysis_results"]
    
    # 최신 분석 결과 검토
    recent_analysis = "\n\n".join(analysis_results[-2:])
    
    messages = [
        SystemMessage(content="""
            당신은 연구 품질 검증 전문가입니다.
            분석 결과를 검토하고 다음을 판단하세요:
            1. 정보의 충분성 (충분한가?)
            2. 정보의 신뢰성 (출처가 믿을만한가?)
            3. 논리의 일관성 (모순이 없는가?)
            4. 추가 조사 필요 여부

            반드시 다음 형식으로 시작하세요:
            STATUS: PASSED 또는 STATUS: NEEDS_MORE_RESEARCH

            그 다음 상세한 피드백을 제공하세요."""),
        HumanMessage(content=f"주제: {topic}\n\n분석 결과:\n{recent_analysis}\n\n검증 결과를 제공하세요.")
    ]
    
    response = llm.invoke(messages)
    verification_result = response.content
    
    # 검증 상태 파싱
    if "STATUS: PASSED" in verification_result:
        status = "passed"
        needs_more = False
        print(f"[검증 에이전트] 검증 통과")
    else:
        status = "needs_more_research"
        needs_more = True
        print(f"[검증 에이전트] 추가 조사 필요")
    
    return {
        "verification_status": status,
        "verification_feedback": verification_result,
        "needs_more_research": needs_more
    }

# %% [markdown]
# ### 3.6 조정 에이전트

# %%
def coordination_agent(state: ResearchState) -> dict:
    """
    워크플로우를 제어하고 다음 단계를 결정하는 에이전트
    동적으로 설정된 최대 반복 횟수를 사용
    """
    iteration = state["iteration_count"]
    needs_more = state["needs_more_research"]
    max_iterations = state.get("max_iterations", 3)  # 동적 최대 반복 횟수
    
    if needs_more and iteration < max_iterations:
        print(f"[조정 에이전트] 추가 조사 필요 - 검색으로 돌아갑니다 (반복 {iteration}/{max_iterations})")
        return {}
    elif iteration >= max_iterations:
        print(f"[조정 에이전트] 최대 반복 횟수 도달 ({max_iterations}회) - 현재 결과로 진행합니다")
        return {
            "needs_more_research": False,
            "verification_status": "max_iterations_reached"
        }
    else:
        print(f"[조정 에이전트] 연구 완료 - 보고서 작성 단계로 진행")
        return {}

# %% [markdown]
# #### Human-in-the-loop 노드

# %%
# Human-in-the-loop 노드
def human_review_node(state: ResearchState) -> dict:
    """
    사용자의 승인을 받는 노드 (Human-in-the-loop)
    """
    print("\n" + "="*80)
    print("[Human-in-the-loop] 사용자 검토 요청")
    print("="*80)
    print(f"현재 반복: {state['iteration_count']}/{state.get('max_iterations', 3)}")
    print(f"검증 상태: {state['verification_status']}")
    print(f"\n검증 피드백:\n{state['verification_feedback']}")
    print("="*80)
    
    # 실제 구현에서는 input()을 사용하지만, 
    # 자동 테스트를 위해 기본값 제공
    user_input = input("\n계속 진행하시겠습니까? (yes/no, 기본값: yes): ").strip().lower()
    
    if not user_input:
        user_input = "yes"
    
    approval = user_input in ["yes", "y", ""]
    
    if approval:
        print("[Human-in-the-loop] 승인됨 - 계속 진행")
    else:
        print("[Human-in-the-loop] 거부됨 - 워크플로우 중단")
    
    return {
        "human_approval": approval
    }

# %% [markdown]
# ### 3.7 보고서 에이전트

# %%
def report_agent(state: ResearchState) -> dict:
    """
    모든 연구 결과를 종합하여 최종 보고서를 작성하는 에이전트
    """
    topic = state["topic"]
    plan = state["research_plan"]
    all_search = "\n\n".join(state["search_results"])
    all_analysis = "\n\n".join(state["analysis_results"])
    iterations = state["iteration_count"]
    
    messages = [
        SystemMessage(content="""
            당신은 연구 보고서 작성 전문가입니다.
            수집되고 분석된 모든 정보를 종합하여 체계적인 최종 보고서를 작성하세요:

            1. 요약 (Executive Summary)
            2. 연구 배경 및 목적
            3. 주요 발견사항
            4. 상세 분석
            5. 결론 및 제언
            6. 한계점 및 향후 연구 방향

            전문적이고 명확한 보고서를 작성하세요."""),
        HumanMessage(content=f"""
            주제: {topic}

            연구 계획:
            {plan}

            검색 결과:
            {all_search}

            분석 결과:
            {all_analysis}

            (총 {iterations}회 반복 조사 수행)

            위 내용을 바탕으로 최종 보고서를 작성하세요.""")
    ]
    
    response = llm.invoke(messages)
    report = response.content
    
    print(f"[보고서 에이전트] 최종 보고서 작성 완료")
    
    return {
        "final_report": report
    }

# %% [markdown]
# ## 4. 동적 라우팅 함수
#
# 조건에 따라 다음 노드를 동적으로 결정하는 라우팅 함수들을 정의합니다.

# %%
def route_after_verification(state: ResearchState) -> Literal["human_review", "coordination"]:
    """
    검증 후 Human-in-the-loop 또는 조정으로 라우팅
    """
    max_iterations = state.get("max_iterations", 3)
    
    # 추가 연구가 필요하거나 최대 반복 도달 시 사람 검토
    needs_review = (
        state["needs_more_research"] or 
        state["iteration_count"] >= max_iterations
    )
    
    if needs_review:
        return "human_review"
    else:
        return "coordination"

# %%
def route_after_human_review(state: ResearchState) -> Literal["coordination", "report"]:
    """
    Human review 후 라우팅
    """
    if not state["human_approval"]:
        # 사용자가 거부한 경우 바로 보고서로 (중단)
        return "report"
    else:
        return "coordination"

# %%
def route_after_coordination(state: ResearchState) -> Literal["planning", "report"]:
    """
    조정 에이전트 후 루프 또는 종료 결정
    동적으로 설정된 최대 반복 횟수 사용
    """
    max_iterations = state.get("max_iterations", 3)
    
    # 추가 연구가 필요하고 최대 반복 미만이면 루프
    if state["needs_more_research"] and state["iteration_count"] < max_iterations:
        return "planning"  # 루프: 계획으로 돌아감
    else:
        return "report"  # 종료: 보고서 작성

# %% [markdown]
# ## 5. 그래프 구성 (동적 워크플로우 + 루프)
#
# 복잡한 워크플로우를 구성합니다. 조건에 따라 경로가 변경되고, 필요시 루프를 돕니다.
#
# ### 그래프 구조
# ```
# 시작
#   |
#   v
# 복잡도
#   |
#   v
# 계획 <----------+
#   |             |
#   v             |
# 검색            | (루프)
#   |             |
#   v             |
# 분석            |
#   |             |
#   v             |
# 검증            |
#   |             |
#   v             |
# Human Review?   |
#   |             |
#   v             |
# 조정 -----------+
#   |
#   v
# 보고서
#   |
#   v
# 종료
# ```

# %%
from langgraph.graph import StateGraph, END

# StateGraph 생성
workflow = StateGraph(ResearchState)

# 노드 추가
workflow.add_node("complexity_level", complexity_level_of_topic_agent)
workflow.add_node("planning", planning_agent)
workflow.add_node("search", search_agent)
workflow.add_node("analysis", analysis_agent)
workflow.add_node("verification", verification_agent)
workflow.add_node("human_review", human_review_node)
workflow.add_node("coordination", coordination_agent)
workflow.add_node("report", report_agent)

# 시작점 설정
workflow.set_entry_point("complexity_level")

# 순차적 연결 (계획 -> 검색 -> 분석 -> 검증)
workflow.add_edge("complexity_level", "planning")
workflow.add_edge("planning", "search")
workflow.add_edge("search", "analysis")
workflow.add_edge("analysis", "verification")

# 검증 후 조건부 라우팅 (Human review 필요 여부)
workflow.add_conditional_edges(
    "verification",
    route_after_verification,
    {
        "human_review": "human_review",
        "coordination": "coordination"
    }
)

# Human review 후 라우팅
workflow.add_conditional_edges(
    "human_review",
    route_after_human_review,
    {
        "coordination": "coordination",
        "report": "report"
    }
)

# 조정 후 조건부 라우팅 (루프 또는 종료)
workflow.add_conditional_edges(
    "coordination",
    route_after_coordination,
    {
        "planning": "planning",  # 루프: 다시 계획으로
        "report": "report"       # 종료: 보고서로
    }
)

# 보고서에서 종료
workflow.add_edge("report", END)

# 그래프 컴파일
app = workflow.compile()

# %% [markdown]
# ## 6. 그래프 시각화 (선택사항)

# %%
from IPython.display import Image, display

try:
    
    display(
        Image(
            app.get_graph().draw_mermaid_png()
        )
    )
except Exception as e:
    print(f"그래프 표시 오류: {e}")

# %% [markdown]
# ## 7. 테스트 예제
#
# 자율 연구 시스템을 실행해봅니다.

# %% [markdown]
# ### 7.1 연구 주제 설정

# %%
research_topic = "LangGraph를 활용한 Multi-Agent 시스템의 장단점과 실제 활용 사례"

print(f"연구 주제: {research_topic}")
# Out:
# 연구 주제: LangGraph를 활용한 Multi-Agent 시스템의 장단점과 실제 활용 사례

# %% [markdown]
# ### 7.2 자율 연구 실행
#
# 주의: Human-in-the-loop 단계에서 사용자 입력이 필요합니다.

# %%
print("=" * 80)
print("자율 연구 시스템 시작")
print("=" * 80)

# 초기 상태
initial_state = {
    "topic": research_topic,
    "research_plan": "",
    "search_results": [],
    "analysis_results": [],
    "verification_status": "",
    "verification_feedback": "",
    "needs_more_research": False,
    "iteration_count": 0,
    "max_iterations": 0,  
    "human_approval": True,
    "final_report": ""
}

# 그래프 실행
# 주의: input()이 호출되므로 실제 실행 시 사용자 입력 필요
result = app.invoke(initial_state)

print("\n" + "=" * 80)
print("연구 완료!")
print("=" * 80)
# Out:
# ================================================================================
# 자율 연구 시스템 시작
# ================================================================================
# [주제의 복잡도 에이전트] 주제 복잡도: 복잡 (최대 4회 반복)
# [계획 에이전트] 연구 계획 수립 완료 (반복 1회 / 최대 0회)
# [검색 에이전트] 웹 검색 실행: LangGraph를 활용한 Multi-Agent 시스템의 장단점과 실제 활용 사례
# [검색 에이전트] 실제 웹 검색 완료 (7개 결과)

# %% [markdown]
# ### 7.3 최종 보고서 확인

# %%
print("\n" + "=" * 80)
print("최종 연구 보고서")
print("=" * 80)
print(f"\n총 반복 횟수: {result['iteration_count']}")
print(f"검증 상태: {result['verification_status']}")
print("\n" + "-" * 80)
print(result["final_report"])
print("-" * 80)
# Out:
# ================================================================================
# 최종 연구 보고서
# ================================================================================
#
# 총 반복 횟수: 2
# 검증 상태: needs_more_research
#
# --------------------------------------------------------------------------------
# 제목: LangGraph를 활용한 Multi-Agent 시스템(MAS)의 장단점과 실제 활용 사례에 관한 연구 보고서
#
# 1. Executive Summary (요약)
# - 목적 및 맥락
#   - 다중 에이전트 시스템에서 그래프 기반 추론의 도입이 협업 효율성, 의사결정 품질, 시스템 확장성에 미치는 구체적 효과를 평가하고, LangGraph의 아키텍처·설계 원칙을 정리하며, 실무 사례를 바탕으로 도입 로드맵을 제시합니다. 본 보고서는 주로 산업 현장의 블로그 글과 실무 가이드를 근거로 하며, LangGraph의 직접적 실증 자료는 제한적임을 명시합니다. (출처: 출처 1, 출처 2, 출처 3)
# - 핵심 발견
#   - 장점 요약: LangGraph는 에이전트 간 흐름의 시각화/추적성을 강화하고 모듈화된 설계를 촉진하며, GraphRAG/AgentRAG 같은 기법과의 결합으로 품질 관리 및 자기 교정 가능성을 높일 수 있습니다. 운영 측면에서도 Kubernetes 기반 CI/CD 같은 자동화와 관찰성 강화와의 연계가 가능하다는 점이 반복적으로 시사됩니다. (출처 2)
#   - 실무 사례의 맥락: 기관 내 LangChain/LangGraph 중심의 서비스 고도화 사례와 로그 기반 탐지/보안 영역의 실무 맥락이 제시되며, LangGraph의 도입으로 서비스 흐름의 추적성과 모듈화가 강화될 수 있다는 시각이 공유됩니다. 다만 LangGraph의 직접적 구체 사례는 제한적이고, 대부분 도메인 맥락에서의 설계 원칙과 구현 전략이 주로 다뤄집니다. (출처 1, 출처 2, 출처 3)
# - 실무 활용 로드맷 제안
#   - 파일럿→MVP→확대의 단계별 설계 원칙, KPI 설정, 리스크 관리, 보안/프라이버시 고려사항과 운영 비용 관리가 권고됩니다. 또한 MVP/파일럿 설계 시 도메인별 우선순위와 데이터 흐름, 로그 포맷의 표준화가 중요합니다. (출처 2)
# - 한계와 주의점
#   - LangGraph에 대한 실증 자료의 한계, 직접적 재현 가능한 벤치마크의 부재, 구현 복잡성 및 운영 비용 증가 가능성은 신중히 고려해야 합니다. 또한 그래프 기반 접근이 모든 문제에 최적은 아닐 수 있기에 도메인-시나리오에 따른 적합성 검토가 필요합니다. (출처 1, 출처 2, 출처 3)
# - 제언의 요지
#   - LangGraph 도입 시 도메인 정의, 모듈화 설계, 품질 관리 전략(Hybrid Search/Reranking), 운영 자동화, 에이전트 자기 교정 메커니즘(GraphRAG/AgentRAG) 등을 통합하는 것이 효과적입니다. 또한 “living bibliography”(계속 업데이트되는 인용 관리) 체계를 운영해 다수의 출처를 교차 검토하는 것이 신뢰성 확보에 중요합니다. (출처 2)
#
# 2. 연구 배경 및 목적
# - 연구 배경
#   - MAS는 에이전트 간의 협업과 의사결정 흐름의 복잡성으로 인해 추적성과 재현성이 중요한 도전 과제로 남아 있습니다. 그래프 기반 추론 및 GraphRAG/AgentRAG 같은 기법은 이러한 흐름의 가시성, 모듈성, 품질 관리에 대한 기대를 높일 수 있습니다.
# - 연구 목적
#   - LangGraph의 아키텍처(예: GraphRAG, AgentRAG 포함)와 도메인 설계 시발점(노드 타입, 엣지 설계, 재구성 전략)을 파악하고, 3–5건의 실무 사례를 통해 성능 지표와 품질 지표를 어떻게 정의하고 측정할 수 있는지 정리합니다.
#   - LangGraph와 대체 프레임워크(전통적 RAG, 그래프 기반 솔루션 등) 간의 차별점과 적합 도메인을 비교하고, 실무 도입을 위한 로드맷(파일럿→MVP→확대)의 핵심 설계 원칙과 성공 판단 기준을 제시합니다.
# - 범위와 한계
#   - 본 보고서는 공개적으로 접근 가능한 블로그 글(출처 1, 출처 2) 및 실무 가이드를 바탕으로 하며, LangGraph의 공식 문서나 학술 연구가 보완될 경우 근거를 업데이트하는 living document로서의 활용을 권장합니다. (출처 1–3)
#
# 3. 주요 발견사항
# - LangGraph의 가치 포인트
#   - 서비스 흐름의 가시성/추적성 강화: 다수의 에이전트 간 상호작용과 흐름을 그래프로 관리하고 추적하는 것이 디버깅과 성능 개선에 유리합니다. (출처 2)
#   - 모듈화된 설계 촉진: LangChain/AutoGen/CrewAI 같은 도구와의 연계로 에이전트를 모듈화하고, LangGraph로 흐름과 의존성을 관리하는 설계가 촉진됩니다. (출처 2)
#   - 품질 관리 및 도메인 적합성 강화: Hybrid Search, Reranking 등의 기법과 GraphRAG/AgentRAG의 결합으로 품질 향상 및 도메인 맞춤형 튜닝의 가능성이 커집니다. (출처 2)
#   - 운영 자동화 및 생산성 향상: Kubernetes 기반 CI/CD, 운영 대시보드 연계 등 생산성 향상에 기여 가능성이 제시됩니다. (출처 2)
#   - 에이전트 자기 교정 가능성: GraphRAG/AgentRAG를 활용한 에이전트 교정 및 개선이 가능하다는 시나리오가 제시됩니다. (출처 2)
# - 실무 사례의 맥락
#   - 사례 A(로그 패턴 기반 위협 탐지): 실제 보안 영역에서 멀티 에이전트 협업의 가능성을 보여주며, LangGraph 직접 언급은 없으나 MAS 설계의 실무 맥락을 제공합니다. (출처 1)
#   - 사례 B(서비스 고도화/In-팀 LangGraph 중심 운영): LangChain/LangGraph/AutoGen/CrewAI 연계, GPU 효율성, 추론 속도 고려, GraphRAG/AgentRAG 도입 등 구체적 설계 원칙과 운영 전략이 제시됩니다. (출처 2)
#   - 사례 C(실무 가이드: LangChain 중심): LangGraph 직접 사례는 제한적이지만, LangChain 기반 에이전트 서비스 구축의 실무 관점을 제공해 MAS 설계의 실무 맥락을 보완합니다. (출처 3)
# - 한계와 주의점
#   - 직접적 실증 자료의 한계: LangGraph의 구체적 구현 사례와 재현 가능한 벤치마크가 충분치 않으며, 블로그 포스트 수준의 자료에 의존하는 부분이 큽니다. (출처 1–3)
#   - 구현 복잡성 및 비용 증가 가능성: 그래프 기반 설계 특성상 초기 도입과 운영에 추가 비용/노력이 필요할 수 있습니다. (출처 1, 2)
#   - 모든 문제에 그래프가 최적은 아님: 도메인 특성과 시나리오에 따라 그래프 기반 접근이 과도하거나 부적합할 수 있습니다. (출처 2)
# - 전략적 시사점
#   - LangGraph 도입은 도메인 정의, 모듈화, 품질 관리 전략, 운영 자동화, 에이전트 자기 교정의 통합을 통해 가시성·재사용성·품질 개선의 순환 고리를 형성할 수 있습니다. (출처 2)
#
# 4. 상세 분석
# 4.1 LangGraph 아키텍처 및 구성 요소 (개념적 프레임)
# - 핵심 구성 요소
#   - GraphRAG: 그래프 기반의 정보 검색/추론 보강을 위한 구성요소. 그래프에 저장된 노드/엣지 정보를 활용하여 질의에 대한 보강된 응답을 생성하는 흐름으로 이해됩니다. (출처 2)
#   - AgentRAG: 에이전트 간 협업에서 각 에이전트의 의사결정 루프를 그래프 맥락 안에서 조정하고 교정하는 역할로 제시됩니다. (출처 2)
# - 노드/엣지 설계(권장 방향성)
#   - 노드 타입 예시: Agent, 데이터 객체, 이벤트/작업, 상태, 도메인 지식 등
#   - 엣지 타입 예시: 의존성, 상호작용, 데이터 흐름, 결과 반환 경로, 재학습/재구성 트리거
#   - 재구성 전략: 도메인 특성에 따라 그래프를 주기적으로 재구성하고, 이벤트 기반의 재구성 트리거를 도입하는 방향이 제시됩니다.
# - API/아키텍처 연계성
#   - LangGraph와 LangChain의 모듈화·연계를 통해 에이전트를 구성하고 흐름을 관리하는 설계가 강조됩니다. (출처 2)
#
# 4.2 실무 사례의 상세 분석
# - 사례 A: 로그 패턴 분석 기반 위협 탐지 시스템
#   - 요지: 특정 로그 패턴을 감지하는 모델과 오류 대응의 구조를 다루며, 멀티 에이전트 구성의 실무 적용 맥락을 보여줍니다.
#   - LangGraph 직접성: 본 사례에서 LangGraph의 직접 언급은 없으나, MAS 설계의 현실적 사용 사례로 해석될 수 있습니다. (출처 1)
# - 사례 B: LangChain/LangGraph 중심의 서비스 고도화
#   - 요지: GPU 효율성과 추론 속도 고려, 모델 간 연계 설계의 중요성, Hybrid Search 및 Reranking의 도입으로 품질 관리 강화, LangGraph를 통한 서비스 고도화 및 추적성 확보를 제시합니다. GraphRAG/AgentRAG를 통한 질의 교정과 개선 사례도 언급됩니다. (출처 2)
# - 사례 C: LangChain 실무 가이드(실전 구현 중심)
#   - 요지: LangChain 기반 에이전트 서비스 구축의 실무적 방법론을 다루며, LangGraph의 직접 사례보다는 실무 구현의 맥락 보완 자료로 간주됩니다. (출처 3)
#
# 4.3 비교 연구 방향
# - LangGraph vs 전통적 RAG/그래프 기반 솔루션
#   - 차별점: LangGraph의 그래프 기반 흐름 추적과 모듈화, GraphRAG/AgentRAG의 의사결정 교정 등은 품질 관리 및 추적성에 특화된 강점으로 제시됩니다. 전통적 RAG는 정보 검색·보강에 중점을 두는 경향이 있습니다.
#   - 운영 난이도: 그래프 설계/운영의 복잡성, 데이터 파이프라인 관리, 인프라 비용 등의 측면에서 LangGraph 도입 시 추가적인 도전과제가 존재합니다. (출처 2)
# - 도메인 적합성
#   - 보안 탐지, IT 운영 자동화, 데이터 분석 파이프라인 등 도메인 특성에 따라 그래프 기반 MAS의 이점이 달라질 수 있습니다. 도메인별 맞춤 튜닝이 중요하다는 시사점도 반복됩니다. (출처 2, 출처 1)
#
# 4.4 위험 관리 및 설계 원칙
# - 보안/프라이버시
#   - 데이터 흐름 관리, 접근 권한, 감사 로깅 및 저장/전송 암호화 등 보안 관리가 필수이며, 벤더 종속성 문제를 완화하는 거버넌스가 필요합니다. (출처 2)
# - 운영 비용 및 기술 역량
#   - 그래프 기반의 추적/재구성은 초기 투자와 운영 비용 증가 가능성을 내포합니다. 따라서 MVP 단계에서 비용-효익 분석과 역량 확보 계획이 필요합니다. (출처 2)
# - 신뢰성과 해석 가능성
#   - 다수의 에이전트의 의사결정에 대한 해석 가능성과 책임 소재를 명확히 하는 설계가 중요합니다. (출처 2)
#
# 4.5 연구 설계 및 실행 로드맷 (간단한 실행 계획)
# - Phase 0: 자료 정리 및 출처 확정 (약 2주)
#   - 산출물: LangGraph 공식 문서 요약, GraphRAG/AgentRAG 매핑표, 용어집
# - Phase 1: 파일럿 설계 및 MVP 프레임(약 3–4주)
#   - 산출물: MVP 설계 초안, 에이전트 수, 그래프 구조, 주요 KPI, 요구사항 목록
#   - 활동: 파일럿 시나리오 정의, 데이터 흐름 및 모니터링 포인트 결정
# - Phase 2: MVP 구현 및 초기 평가(약 6–8주)
#   - 산출물: 구현 시나리오, 성능/품질 측정 계획, 로그/메트릭 체계 구성
#   - 활동: 파일럿 구현, 지연/메모리/정확도 측정
# - Phase 3: 결과 분석 및 도메인 적합성 평가(약 4주)
#   - 산출물: 정량적 평가 보고서, 도메인 적합성 평가, 확장 방안 제안
# - Phase 4: 로드맷 확정 및 실무 가이드(약 2주)
#   - 산출물: 운영 권고사항, ROI 시나리오, 실행 체크리스트 및 MVP 설계 초안
# - 운영 원칙
#   - MVP 설계 시 도메인별 파일럿 템플릿, 데이터 흐름 다이어그램, 로그 포맷 표준의 사전 정의 필요
#
# 4.6 신뢰성 강화 포인트
# - 출처 간 교차 검토 및 다중 출처 근거 확보
# - 재현 가능한 실험 프로토콜 및 로그 표준화
# - Living bibliography 운영으로 인용 관리 및 지속 업데이트
# - MVP 파일럿의 구체 구현 예제 및 데이터 흐름 다이어그램 제공
#
# 4.7 실무 활용을 위한 부가 제안
# - 상황 맞춤 체크리스트와 MVP 설계 템플릿 제공
# - LangGraph API/구현 예제 요약본(필요 시)
# - 도메인별 파일럿 설계 템플릿(2개 도메인 추천 예시 포함)
#
# 5. 결론 및 제언
# - 결론 요지
#   - LangGraph는 에이전트 간 협력 흐름의 추적성과 모듈화를 강화하고, GraphRAG/AgentRAG 등 보강 기법과 결합하면 품질 관리 및 자기 교정 가능성을 높일 수 있습니다. LangChain과의 연계성은 모듈화 및 흐름 관리 측면에서 시너지를 제공할 수 있습니다. (출처 2)
#   - 실무 사례로는 보안 위협 탐지와 같이 멀티 에이전트 협업의 실제 맥락에서 적용 가능성이 시사되며, LangGraph를 이용한 서비스 고도화 및 추적성 확보의 가능성도 제시됩니다. (출처 1, 출처 2)
# - 실무에 대한 권고
#   - 도메인 정의와 모듈화 설계의 선행, 품질 관리 전략(Hybrid Search, Reranking) 및 GraphRAG/AgentRAG 도입 여부 검토
#   - 운영 자동화(Kubernetes 기반 CI/CD) 및 모니터링 체계 구축
#   - 보안/프라이버시 및 거버넌스, 벤더 종속성 관리에 대한 선제적 설계
#   - 파일럿을 통한 KPI 정의 및 RIO 측정: 추론 지연, 메모리 사용량, 정확도/일관성, 비용/ROI를 기본 지표로 삼고, 개선 포인트를 에이전트 교정 루프에서 탐색
# - 도메인별 로드맷 제안
#   - 1–2개 도메인에서의 파일럿 설계 템플릿 제공(예: 보안 모니터링, IT 운영 자동화)
#   - MVP 설계의 핵심 목표, 데이터 흐름, 역할 분해, 성능 목표 포함
#
# 6. 한계점 및 향후 연구 방향
# - 한계 요약
#   - LangGraph의 직접적 실증 자료가 제한적이며, 주로 블로그 포스트 수준의 실무 서술에 의존합니다. 따라서 재현 가능한 벤치마크나 공인된 연구 데이터가 충분하지 않습니다.
#   - 구현의 복잡성 및 운영 비용 증가 가능성, 그래프 기반 설계의 필요성 여부가 도메인에 따라 다를 수 있습니다.
# - 향후 연구 방향
#   - LangGraph의 공식 문서/API 가이드, GraphRAG/AgentRAG의 작동 원리 및 연동 예제의 구체적 사례 확보
#   - 동일 워크로드에 대한 LangGraph vs 전통 RAG, 그래프 기반 솔루션 간의 벤치마크 연구
#   - 3–5개 산업 사례 외 도메인 확장(제조, IT 운영, 고객 서비스 등)에 대한 사례 연구
#   - 데이터 파이프라인, 인덱싱 전략, Hybrid Search/Reranking의 실무적 설계 원칙 및 성능 영향 분석
#   - 거버넌스, 책임 소재, 해석 가능성 향상을 위한 실무 프레임워크 제시
#   - 재현성 있는 실험 프로토콜, 로그 포맷 표준화 및 데이터 흐름 다이어그램의 공개 템플릿 개발
#
# 7. 참고 및 인용 포인트 관리
# - 출처 1: 블로그 글(위협 탐지 사례)으로, LangGraph의 직접적 활용 사례를 다루기보단 MAS의 실무 맥락에서의 적용 가능성을 보여줍니다. LangGraph의 직접적 언급은 제한적입니다. (출처 1)
# - 출처 2: LangChain/LangGraph/AutoGen/CrewAI 등 멀티 에이전트 프레임워크의 통합적 이해와 도구 간 연계 설계의 중요성, GraphRAG/AgentRAG의 활용 가능성, GPU 효율성 및 운영 자동화에 대한 논의가 상세히 제시됩니다. 또한 LangGraph를 활용한 서비스 고도화 및 추적성 강화를 강조합니다. (출처 2)
# - 출처 3: LangChain 기반의 실무 구현 가이드를 다룬 실전 도서 소개로, LangGraph의 직접 사례는 제한적이지만 실무 구현 역량 강화에 유용합니다. (출처 3)
#
# 8. 부록: 실무 활용을 위한 템플릿 및 체크리스트 제안
# - 인용 관리 표(Living bibliography) 템플릿
# - MVP 설계 초안 템플릿(아키텍처 목표, 역할 분해, 데이터 흐름, 성능 목표 포함)
# - 평가 체크리스트(추적성, 품질, 성능, 비용, 보안/거버넌스 항목별 체크리스트)
# - 파일럿/실험 계획서 템플릿(실험 목표, 데이터셋, 로그 포맷, 메트릭 정의, 재현성 확보 절차)
#
# 요약 및 마무리
# - 본 보고서는 LangGraph를 중심으로 MAS의 장점과 한계를 정리하고, 실무 사례를 바탕으로 도입 로드맷을 제시합니다. LangGraph의 직접적 실증 자료는 아직 제한적이므로, 공식 문서 및 다수의 독립 자료를 교차 검토하며 파일럿을 통해 KPI를 검증하는 접근이 바람직합니다. 또한 GraphRAG/AgentRAG 등의 기법 도입으로 질의 개선 및 자기 교정의 가능성이 엿보이나, 도메인별 적합성 검토와 운영 비용 관리가 필수입니다.
# - 필요 시, 귀사 상황에 맞춘 구체적인 평가 체크리스트와 MVP 설계 초안, 그리고 API/구현 예제 요약본을 제공드리겠습니다. 이 보고서는 두 차례의 검색 결과를 바탕으로 한 분석의 합성물이며, 향후 공식 문서 및 추가 사례 연구를 반영하여 업데이트될 living document로 활용하시길 권합니다.
#
# 참고 및 출처
# - 출처 1: 블로그 글(로그 패턴 분석 기반 위협 탐지 시스템) — LangGraph 직접 언급은 제한적이나 MAS의 실무 맥락에 대한 시사점 제시. (출처 1)
# - 출처 2: LangChain/LangGraph/AutoGen/CrewAI 등 멀티 에이전트 프레임워크의 이해와 설계 원칙, GraphRAG/AgentRAG의 활용, GPU 효율성/추론 속도, 모듈화와 추적성 강화, 운영 자동화에 관한 실무 논의. (출처 2)
# - 출처 3: 『조코딩의 랭체인으로 AI 에이전트 서비스 만들기』 — LangChain 중심의 실무 구현 가이드, LangGraph의 구체적 사례보다는 실무 구현 맥락 보완. (출처 3)
#
# 추가로 원하시면
# - 특정 비즈니스 상황을 가정한 LangGraph 기반 MAS 설계 초안(에이전트 구성, 데이터 흐름, KPI 포함)과 간단한 평가 계획
# - 또는 각 출처의 인용 포인트를 깔끔한 인용 요약으로 정리해 드리겠습니다
#
# 문의 사항이나 원하시는 도메인(예: 보안 모니터링, IT 운영 자동화, 고객 서비스 등)에 맞춘 파일럿 템플릿도 함께 작성해 드리겠습니다.
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 7.4 연구 과정 추적

# %%
print("\n" + "=" * 80)
print("연구 과정 추적")
print("=" * 80)

print(f"\n[검색 결과 수집]: {len(result['search_results'])}회")
for i, search in enumerate(result['search_results'], 1):
    print(f"\n--- 검색 {i} ---")
    print(search[:200] + "..." if len(search) > 200 else search)

print(f"\n\n[분석 수행]: {len(result['analysis_results'])}회")
for i, analysis in enumerate(result['analysis_results'], 1):
    print(f"\n--- 분석 {i} ---")
    print(analysis[:200] + "..." if len(analysis) > 200 else analysis)
# Out:
# ================================================================================
# 연구 과정 추적
# ================================================================================
#
# [검색 결과 수집]: 2회
#
# --- 검색 1 ---
#
#     [실제 웹 검색 결과 - 반복 1]
#
#     다음은 제시된 검색 결과를 바탕으로, LangGraph를 활용한 Multi-Agent 시스템의 장단점과 실제 활용 사례를 정리한 분석 요약입니다.
#
# 1) 출처별 주요 내용 요약
#
# - 출처 1 (블로그, 위협 탐지 사례)
#   - 주요 내용: 실제로 적용된 사례로, 로그 패턴 분석 기반 위협 탐지 시스템이 ...
#
# --- 검색 2 ---
#
#     [실제 웹 검색 결과 - 반복 2]
#
#     다음은 주제인 “LangGraph를 활용한 Multi-Agent 시스템(MAS)의 장단점과 실제 활용 사례”에 대해 주어진 검색 결과를 요약하고 분석한 내용입니다.
#
# 1) 출처별 요약
#
# - 출처 1 (https://blog.naver.com/n_cloudplatform/223938853841)
#   - 핵...
#
#
# [분석 수행]: 2회
#
# --- 분석 1 ---
# [분석 결과 - 반복 1]
# 다음은 제시된 검색 결과를 바탕으로 한 LangGraph를 활용한 Multi-Agent 시스템 분석입니다. 핵심 패턴, 주요 발견, 상충 정보 여부, 그리고 추가 조사 필요 영역을 정리했습니다.
#
# 1) 분석의 요지 요약
# - LangGraph의 주된 가치는 에이전트 간 흐름의 추적성과 모듈화에 있으며, 품질 관리(Hybrid Sea...
#
# --- 분석 2 ---
# [분석 결과 - 반복 2]
# 다음은 주어진 검색 결과를 토대로, LangGraph를 활용한 Multi-Agent 시스템(MAS)의 장단점과 실제 활용 사례를 분석한 정리입니다.
#
# 1) 핵심 패턴과 트렌드 파악
# - 모듈화와 연결성의 강화
#   - LangChain/LangGraph/AutoGen 등 여러 에이전트 프레임워크를 조합해 에이전트를 모듈화하고, 서로 ...
