# %% [markdown]
# # Supervisor Agent란?
#
# **Supervisor Agent**는 Hierarchical Agent의 특수한 형태로, 여러 전문 에이전트들을 **관리하고 조율**하는 역할을 합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 주요 특징
# 1. **중앙 집중식 제어**: Supervisor가 전체 워크플로우를 관리
# 2. **동적 작업 배분**: 상황에 따라 적절한 에이전트에게 작업 할당
# 3. **결과 종합**: 여러 에이전트의 결과를 수집하고 통합
# 4. **순차적 조율**: 필요시 에이전트 간 작업 순서 조정
#
# ## vs. 단순 Hierarchical Agent
# - **Hierarchical**: 단순히 작업을 분류하여 해당 에이전트로 전달 (1회성)
# - **Supervisor**: 전체 프로세스를 관리하며, 여러 에이전트를 순차적으로 호출하고 결과를 통합 (다단계)

# %% [markdown]
# # Supervisor Agents - 블로그 콘텐츠 제작 시스템
#
# Supervisor Agent 패턴을 활용하여 블로그 콘텐츠를 자동으로 제작하는 시스템을 구현합니다.

# %% [markdown]
# ## 시스템 구성
#
# ### 에이전트 구조
# ```
#                     Supervisor Agent
#                     (콘텐츠 제작 관리자)
#                            |
#          +-----------------+-----------------+
#          |                 |                 |
#     Research Agent    Writer Agent      SEO Agent
#     (자료 조사)        (초안 작성)       (SEO 최적화)
#          |                 |                 |
#          +-----------------+-----------------+
#                            |
#                     Editor Agent
#                     (최종 편집)
# ```
#
# ### 작업 흐름
# 1. **Supervisor**: 블로그 주제를 분석하고 작업 계획 수립
# 2. **Research Agent**: 주제 관련 정보 조사 및 핵심 포인트 추출
# 3. **Writer Agent**: 조사 자료를 바탕으로 초안 작성
# 4. **SEO Agent**: 키워드 최적화 및 SEO 권장사항 제시
# 5. **Editor Agent**: 최종 편집 및 교정
# 6. **Supervisor**: 모든 결과를 종합하여 최종 콘텐츠 생성

# %% [markdown]
# ## 학습 목표
#
# - Supervisor Agent의 역할과 책임 이해
# - 다단계 워크플로우 설계 및 구현
# - 에이전트 간 데이터 전달 및 상태 관리
# - 동적 작업 조율 (Dynamic Task Orchestration)

# %% [markdown]
# ## 1단계: LLM 모델 초기화

# %%
from langchain_ollama.chat_models import ChatOllama

llm = ChatOllama(
    model="gemma3:4b",
    temperature=0.7,  # 창의적인 콘텐츠 생성을 위해 약간 높임
    top_p=1.0,
    keep_alive="5m"
)

# %% [markdown]
# ## 2단계: 상태 정의 (State Management)
#
# Supervisor Agent 시스템에서는 여러 에이전트가 순차적으로 작업하므로, 각 단계의 결과를 저장할 수 있는 복잡한 상태 구조가 필요합니다.

# %%
from typing import TypedDict, Literal

# total=False는 TypedDict의 모든 필드를 선택적(optional)으로 만드는 옵션
class ContentState(TypedDict, total=False):
    """
    블로그 콘텐츠 제작 시스템의 상태를 정의하는 클래스
    """
    # 입력
    topic: str                      # 블로그 주제
    target_audience: str            # 타겟 독자층
    
    # Supervisor 관리
    current_step: str               # 현재 진행 단계
    next_agent: str                 # 다음 실행할 에이전트
    
    # 각 에이전트의 작업 결과
    research_data: str              # Research Agent의 조사 결과
    draft_content: str              # Writer Agent의 초안
    seo_recommendations: str        # SEO Agent의 권장사항
    edited_content: str             # Editor Agent의 최종 편집본
    
    # 최종 출력
    final_blog_post: str            # 완성된 블로그 포스트
    status: Literal['in_progress', 'completed']  # 작업 상태

# %% [markdown]
# ## 3단계: 전문 에이전트 정의
#
# 각 에이전트는 특정 영역의 전문가 역할을 수행합니다.

# %% [markdown]
# ### Research Agent (조사 에이전트)
#
# 주제에 대한 핵심 정보를 조사하고 정리합니다.

# %%
from langchain_core.messages import HumanMessage, SystemMessage

def research_agent(state: ContentState) -> ContentState:
    """
    주제에 대한 조사를 수행하는 에이전트
    """
    topic = state["topic"]
    target_audience = state["target_audience"]
    
    messages = [
        SystemMessage(content="""
            당신은 전문 리서처입니다.
            주어진 주제에 대해 다음 항목을 조사하여 정리하세요:
            
            1. 주제의 핵심 개념 및 정의
            2. 주요 트렌드 및 최신 동향
            3. 독자들이 궁금해할 만한 점 3가지
            4. 실용적인 팁이나 인사이트
            5. 관련 통계나 데이터 (있다면)
            
            간결하고 구조화된 형태로 작성하세요."""),
        HumanMessage(content=f"""
            주제: {topic}
            타겟 독자: {target_audience}
            
            위 주제에 대해 조사해주세요.""")
    ]
    
    response = llm.invoke(messages)
    research_data = response.content
    
    print("[Research Agent] 조사 완료")
    print(f"조사 결과 길이: {len(research_data)} 자")
    
    return {
        **state,
        "research_data": research_data,
        "current_step": "research_completed",
        "next_agent": "writer"
    }

# %% [markdown]
# 블로그 초안을 작성하는 에이전트

# %%
def writer_agent(state: ContentState) -> ContentState:
    """
    블로그 초안을 작성하는 에이전트
    """
    topic = state["topic"]
    research_data = state["research_data"]
    target_audience = state["target_audience"]
    
    messages = [
        SystemMessage(content="""
            당신은 전문 블로그 작가입니다.
            조사 자료를 바탕으로 매력적인 블로그 포스트 초안을 작성하세요.
            
            구조:
            1. 흥미를 끄는 서론
            2. 본론 (3-4개 섹션)
            3. 실용적인 조언이나 팁
            4. 요약 및 결론
            
            문체:
            - 친근하고 읽기 쉬운 문체
            - 독자에게 직접 말하는 듯한 톤
            - 적절한 예시와 설명 포함"""),
        HumanMessage(content=f"""
            주제: {topic}
            타겟 독자: {target_audience}
            
            조사 자료:
            {research_data}
            
            위 자료를 바탕으로 블로그 포스트 초안을 작성해주세요.""")
    ]
    
    response = llm.invoke(messages)
    draft_content = response.content
    
    print("[Writer Agent] 초안 작성 완료")
    print(f"초안 길이: {len(draft_content)} 자")
    
    return {
        **state,
        "draft_content": draft_content,
        "current_step": "draft_completed",
        "next_agent": "seo"
    }

# %% [markdown]
# SEO 최적화 권장사항을 제공하는 에이전트

# %%
def seo_agent(state: ContentState) -> ContentState:
    """
    SEO 최적화 권장사항을 제공하는 에이전트
    """
    topic = state["topic"]
    draft_content = state["draft_content"]
    
    messages = [
        SystemMessage(content="""
            당신은 SEO 전문가입니다.
            블로그 초안을 분석하여 검색엔진 최적화 권장사항을 제시하세요.
            
            분석 항목:
            1. 추천 키워드 5-7개 (주 키워드 + 롱테일 키워드)
            2. 메타 디스크립션 제안 (150-160자)
            3. 제목 개선안 (SEO 친화적)
            4. 헤딩 구조 개선 제안
            5. 내부/외부 링크 권장사항
            
            간결하고 실행 가능한 조언을 제공하세요."""),
        HumanMessage(content=f"""
            주제: {topic}
            
            초안:
            {draft_content[:1000]}... (초반부)
            
            SEO 최적화 권장사항을 제시해주세요.""")
    ]
    
    response = llm.invoke(messages)
    seo_recommendations = response.content
    
    print("[SEO Agent] SEO 분석 완료")
    
    return {
        **state,
        "seo_recommendations": seo_recommendations,
        "current_step": "seo_completed",
        "next_agent": "editor"
    }

# %% [markdown]
# ### Editor Agent (편집 에이전트)
#
# 초안과 SEO 권장사항을 반영하여 최종 편집본을 만듭니다.

# %%
def editor_agent(state: ContentState) -> ContentState:
    """
    최종 편집 및 교정을 수행하는 에이전트
    """
    draft_content = state["draft_content"]
    seo_recommendations = state["seo_recommendations"]
    
    messages = [
        SystemMessage(content="""
            당신은 전문 에디터입니다.
            초안을 검토하고 SEO 권장사항을 반영하여 최종 편집본을 만드세요.
            
            편집 작업:
            1. 문법 및 맞춤법 교정
            2. 문장 흐름 개선
            3. SEO 키워드 자연스럽게 삽입
            4. 제목과 소제목 최적화
            5. 가독성 향상 (단락 나누기, 불릿 포인트 활용)
            
            원본의 핵심 메시지는 유지하되, 더 세련되고 전문적으로 다듬으세요."""),
        HumanMessage(content=f"""
            초안:
            {draft_content}
            
            SEO 권장사항:
            {seo_recommendations}
            
            위 내용을 반영하여 최종 편집본을 작성해주세요.""")
    ]
    
    response = llm.invoke(messages)
    edited_content = response.content
    
    print("[Editor Agent] 최종 편집 완료")
    
    return {
        **state,
        "edited_content": edited_content,
        "current_step": "editing_completed",
        "next_agent": "supervisor"
    }

# %% [markdown]
# ## 4단계: Supervisor Agent 정의
#
# **핵심!** Supervisor Agent는 전체 워크플로우를 관리하고 조율합니다.

# %%
def supervisor_agent(state: ContentState) -> ContentState:
    """
    전체 콘텐츠 제작 프로세스를 관리하는 Supervisor Agent
    """
    current_step = state.get("current_step", "start")
    
    print(f"\n[Supervisor Agent] 현재 단계: {current_step}")
    
    # 시작 단계: 작업 계획 수립
    if current_step == "start":
        print("[Supervisor] 작업 계획 수립 중...")
        print("  → 1단계: Research Agent 호출 예정")
        print("  → 2단계: Writer Agent 호출 예정")
        print("  → 3단계: SEO Agent 호출 예정")
        print("  → 4단계: Editor Agent 호출 예정")
        print("  → 5단계: 최종 결과 종합 예정")
        
        return {
            **state,
            "current_step": "planned",
            "next_agent": "research",
            "status": "in_progress"
        }
    
    # 모든 에이전트 작업 완료: 최종 결과 종합
    elif current_step == "editing_completed":
        print("[Supervisor] 모든 에이전트 작업 완료. 최종 결과 종합 중...")
        
        final_blog_post = f"""
            # 블로그 콘텐츠 제작 완료

            ## 메타 정보
            **주제:** {state['topic']}
            **타겟 독자:** {state['target_audience']}

            ---

            ## 최종 콘텐츠

            {state['edited_content']}

            ---

            ## SEO 권장사항

            {state['seo_recommendations']}

            ---

            ## 제작 프로세스
                조사 완료 (Research Agent)
                초안 작성 완료 (Writer Agent)
                SEO 분석 완료 (SEO Agent)
                최종 편집 완료 (Editor Agent)
        """
        
        print("[Supervisor] 최종 블로그 포스트 생성 완료!")
        
        return {
            **state,
            "final_blog_post": final_blog_post,
            "current_step": "completed",
            "next_agent": "end",
            "status": "completed"
        }
    
    # 기타 단계: 다음 에이전트로 진행
    else:
        return state

# %% [markdown]
# ## 5단계: 조건부 라우팅

# %%
from typing import Literal

def route_to_next_agent(state: ContentState) -> Literal["research", "writer", "seo", "editor", "supervisor", "end"]:
    """
    Supervisor의 지시에 따라 다음 에이전트로 라우팅
    """
    next_agent = state.get("next_agent", "research")
    
    print(f"[Router] 다음 에이전트로 이동: {next_agent}")
    
    if next_agent == "end":
        return "end"
    
    return next_agent

# %% [markdown]
# ## 6단계: 그래프 구성
#
# Supervisor Agent 패턴의 핵심: **순환 구조**를 만들어 Supervisor가 각 단계를 조율합니다.

# %%
from langgraph.graph import StateGraph, END, START

# StateGraph 생성
workflow = StateGraph(ContentState)

# 모든 노드 추가
workflow.add_node("supervisor", supervisor_agent)
workflow.add_node("research", research_agent)
workflow.add_node("writer", writer_agent)
workflow.add_node("seo", seo_agent)
workflow.add_node("editor", editor_agent)

# 시작점: Supervisor로 시작
workflow.add_edge(START, "supervisor")

# Supervisor에서 조건부 라우팅
workflow.add_conditional_edges(
    "supervisor",
    route_to_next_agent,
    {
        "research": "research",
        "writer": "writer",
        "seo": "seo",
        "editor": "editor",
        "supervisor": "supervisor",
        "end": END
    }
)

# 각 전문 에이전트는 작업 후 다음 에이전트로 직접 이동
# (Supervisor를 거치지 않고 효율성 향상)
workflow.add_edge("research", "writer")
workflow.add_edge("writer", "seo")
workflow.add_edge("seo", "editor")

# Editor는 작업 후 Supervisor에게 보고
workflow.add_edge("editor", "supervisor")

# 그래프 컴파일
app = workflow.compile()

print("Supervisor Agent 시스템 구성 완료!")
# Out:
# Supervisor Agent 시스템 구성 완료!

# %% [markdown]
# ## 7단계: 그래프 시각화

# %%
from IPython.display import Image, display

try:
    display(
        Image(
            app.get_graph().draw_mermaid_png(max_retries=5, retry_delay=2.0)
        )
    )
except Exception as e:
    print(f"그래프 표시 오류: {e}")

# %% [markdown]
# ## 8단계: 시스템 테스트
#
# 실제 블로그 주제로 전체 프로세스를 테스트해봅니다.

# %% [markdown]
# ### 테스트 케이스: LangChain 가이드 블로그

# %%
# 초기 상태 설정
initial_state = {
    "topic": "개발자를 위한 LangChain 시작 가이드",
    "target_audience": "Python을 다룰 줄 아는 주니어-미들 레벨 개발자"
}

print("=" * 80)
print("블로그 콘텐츠 제작 시작!")
print("=" * 80)
print(f"주제: {initial_state['topic']}")
print(f"타겟 독자: {initial_state['target_audience']}")
print("=" * 80)

# 그래프 실행
result = app.invoke(initial_state)

print("\n" + "=" * 80)
print("블로그 콘텐츠 제작 완료!")
print("=" * 80)
# Out:
# ================================================================================
# 블로그 콘텐츠 제작 시작!
# ================================================================================
# 주제: 개발자를 위한 LangChain 시작 가이드
# 타겟 독자: Python을 다룰 줄 아는 주니어-미들 레벨 개발자
# ================================================================================
#
# [Supervisor Agent] 현재 단계: start
# [Supervisor] 작업 계획 수립 중...
#   → 1단계: Research Agent 호출 예정
#   → 2단계: Writer Agent 호출 예정
#   → 3단계: SEO Agent 호출 예정
#   → 4단계: Editor Agent 호출 예정
#   → 5단계: 최종 결과 종합 예정
# [Router] 다음 에이전트로 이동: research
# [Research Agent] 조사 완료
# 조사 결과 길이: 2633 자
# [Writer Agent] 초안 작성 완료
# 초안 길이: 3115 자
# [SEO Agent] SEO 분석 완료
# [Editor Agent] 최종 편집 완료
#
# [Supervisor Agent] 현재 단계: editing_completed
# [Supervisor] 모든 에이전트 작업 완료. 최종 결과 종합 중...
# [Supervisor] 최종 블로그 포스트 생성 완료!
# [Router] 다음 에이전트로 이동: end
#
# ================================================================================
# 블로그 콘텐츠 제작 완료!
# ================================================================================

# %% [markdown]
# ### 최종 결과 확인

# %%
# 최종 블로그 포스트 출력
print(result["final_blog_post"])
# Out:
#             # 블로그 콘텐츠 제작 완료
#
#             ## 메타 정보
#             **주제:** 개발자를 위한 LangChain 시작 가이드
#             **타겟 독자:** Python을 다룰 줄 아는 주니어-미들 레벨 개발자
#
#             ---
#
#             ## 최종 콘텐츠
#
#             ## LangChain으로 시작하는 LLM 마법: 주니어 개발자를 위한 완벽 가이드
#
# **“GPT-4, PaLM 등 대규모 언어 모델을 활용한 개발을 위한 완벽 가이드! LangChain으로 LLM 개발의 장벽을 낮추고, 당신의 첫 번째 LLM 애플리케이션을 만들 수 있도록 돕습니다.”**
#
# 안녕하세요, 여러분! 저는 여러분의 개발 여정을 돕는 블로그 작가입니다. 최근 대규모 언어 모델(LLM) 기술, 특히 GPT-4, PaLM 등이 급부상하면서, LLM을 활용한 애플리케이션 개발에 대한 관심이 폭발적으로 증가하고 있습니다. 하지만 LLM만으로는 원하는 수준의 복잡한 작업을 수행하기 어려울 때가 많습니다. 바로 이럴 때 LangChain이 여러분의 개발을 돕습니다. LangChain은 LLM을 다양한 데이터 소스와 연결하고, 복잡한 작업을 수행하도록 안내하는 강력한 프레임워크입니다. 이 가이드에서는 LangChain의 핵심 개념을 쉽게 이해하고, 여러분의 첫 번째 LLM 애플리케이션을 만드는 데 필요한 정보를 제공합니다.
#
# **1. LangChain이란 무엇인가? - LLM 개발의 핵심**
#
# LLM은 텍스트를 생성하고 번역하고 요약하는 등 놀라운 능력을 가지고 있지만, 정해진 규칙 없이 자유롭게 작동하는 것은 아닙니다. LangChain은 LLM을 단순히 호출하는 것을 넘어, LLM을 **체인**으로 연결하여 복잡한 작업을 수행하도록 돕습니다. 마치 레고 블록을 조립하듯이, 다양한 구성 요소들을 연결하여 원하는 기능을 구현하는 것이죠.
#
# *   **LLM (Large Language Model):** GPT-3, GPT-4, PaLM 등 방대한 텍스트 데이터를 학습하여 텍스트를 생성, 번역, 요약, 질문 답변 등 다양한 작업을 수행할 수 있는 AI 모델입니다.
# *   **Chain (체인):** LangChain의 핵심 구성 요소로, LLM과 다양한 구성 요소를 연결하여 특정 작업을 수행하는 일련의 단계를 의미합니다. (예: 데이터 로딩 -> 프롬프트 템플릿 -> LLM 호출)
# *   **Agent (에이전트):** LLM을 사용하여 특정 목표를 달성하기 위한 작업을 자동화하는 데 사용됩니다. 다양한 도구를 활용하여 의사 결정을 내리거나, 복잡한 작업을 수행할 수 있습니다.
# *   **Memory (메모리):** LLM이 대화의 맥락을 기억하고 활용할 수 있도록 하는 기능입니다. 턴별로 정보를 저장하거나, 이전 대화 내용을 요약하여 LLM에 제공할 수 있습니다.
#
# **2. LangChain으로 무엇을 만들 수 있을까? - 다양한 LLM 애플리케이션 예시**
#
# LangChain은 정말 다양한 애플리케이션을 만들 수 있도록 설계되었습니다. 몇 가지 예시를 살펴볼까요?
#
# *   **챗봇:** 사용자의 질문에 답변하고, 대화의 맥락을 기억하는 챗봇을 만들 수 있습니다.
# *   **문서 요약 도구:** 긴 문서를 요약하고 핵심 내용을 추출할 수 있습니다.
# *   **Q&A 시스템:** 특정 문서나 데이터베이스에서 질문에 대한 답변을 제공하는 시스템을 구축할 수 있습니다.
# *   **데이터 분석 도구:** LLM을 사용하여 데이터를 분석하고 인사이트를 도출할 수 있습니다.
# *   **자동화된 보고서 생성:**  LLM을 활용하여 데이터 기반의 보고서를 자동으로 생성할 수 있습니다.
#
# **3. LangChain으로 시작하기: 첫 번째 챗봇 만들기 - 튜토리얼**
#
# 자, 이제 실제로 LangChain을 사용해 봅시다. 간단한 챗봇을 만들어보면서 LangChain의 기본 개념과 사용법을 익혀보겠습니다. (코드는 간단하게 요약되어 있으며, LangChain 공식 문서에서 더 자세한 내용을 확인할 수 있습니다.)
#
# (Python 코드 예시 간단하게 요약)
#
# ```python
# from langchain.llms import OpenAI
# from langchain.chains import LLMChain
#
# # OpenAI API 키 설정 (환경 변수에서 가져오는 것을 권장합니다.)
# # openai.api_key = os.getenv("OPENAI_API_KEY")
#
# # LLM 초기화
# llm = OpenAI(temperature=0.7)
#
# # LLMChain 생성
# chain = LLMChain(llm=llm, prompt_template="다음 질문에 답해주세요: {question}")
#
# # 질문 입력
# question = "오늘 날씨는 어때?"
#
# # LLM을 통해 답변 생성
# answer = chain.run(question)
#
# # 답변 출력
# print(answer)
# ```
#
# **4. LangChain 사용법 - 데이터 연결, 프롬프트 템플릿, LLM 호출 - 자세한 설명 추가**
#
# LangChain의 핵심은 데이터를 연결하고, 프롬프트 템플릿을 사용하여 LLM을 효과적으로 호출하고, LLM을 통해 원하는 결과를 얻는 데 있습니다.  각 단계별로 자세히 살펴보겠습니다.
#
# * **데이터 연결:** LangChain은 다양한 데이터 소스(PDF, 웹 페이지, 데이터베이스 등)를 연결할 수 있는 기능을 제공합니다.
# * **프롬프트 템플릿:**  LLM에 전달할 프롬프트 템플릿을 정의하여 LLM의 응답 형식을 제어할 수 있습니다.
# * **LLM 호출:**  프롬프트 템플릿을 기반으로 LLM을 호출하여 응답을 생성합니다.
#
# **5. LangChain 사용하기 -  LLM 개발의 장점 및 커뮤니티 동참**
#
# *   **간편한 통합:** 다양한 LLM, 데이터 소스, 도구와의 통합이 용이합니다.
# *   **확장성:** 복잡한 워크플로우를 구축하고, 새로운 기능을 추가하기 쉽습니다.
# *   **활발한 커뮤니티:**  LangChain은 활발한 오픈 소스 커뮤니티를 통해 지속적으로 업데이트되고 개선되고 있습니다. LangChain 커뮤니티에 참여하여 다른 개발자들과 지식을 공유하고, 도움을 받을 수 있습니다.
#
# **6. LangChain 시작하기 위한 팁 -  성공적인 LLM 개발을 위한 조언**
#
# *   **작은 프로젝트부터 시작하세요:** 복잡한 애플리케이션을 처음부터 개발하려고 하지 말고, 간단한 챗봇이나 문서 요약 도구와 같이 작은 프로젝트부터 시작하여 LangChain의 기본 개념과 기능을 익히세요.
# *   **오류 메시지를 이해하는 연습을 하세요:** LangChain은 복잡한 기능을 제공하므로, 오류 메시지를 이해하는 것이 중요합니다. 오류 메시지를 꼼꼼히 읽고, 관련된 문서를 찾아보면서 문제를 해결하는 연습을 하세요.
# *   **커뮤니티에 참여하세요:** LangChain의 오픈 소스 커뮤니티에 참여하여 다른 개발자들과 지식을 공유하고, 도움을 받을 수 있습니다.
#
# **결론: LangChain으로 LLM의 잠재력을 최대한 활용하세요! -  성공적인 LLM 개발을 위한 메시지**
#
# LangChain은 LLM을 활용하여 혁신적인 애플리케이션을 개발할 수 있도록 돕는 강력한 프레임워크입니다. 이 가이드를 통해 LangChain의 핵심 개념을 이해하고, 여러분의 첫 번째 LLM 애플리케이션을 만드는 데 필요한 지식을 얻었기를 바랍니다. 지금 바로 LangChain으로 LLM의 잠재력을 최대한 활용하여 멋진 애플리케이션을 만들어 보세요!
#
# **참고 자료:**
#
# *   LangChain 공식 문서: [https://www.langchain.com/](https://www.langchain.com/)
# *   LangChain GitHub: [https://github.com/langchain-ai/langchain](https://github.com/langchain-ai/langchain)
#
# ---
#
# 이 블로그 포스트는 다양한 키워드를 포함하고, 가독성을 높이기 위해 문단을 짧게 나누고, 목록(bullet point)를 사용하여 내용을 쉽게 이해하도록 돕습니다. 또한,  LangChain 공식 문서 및 GitHub 링크를 제공하여 사용자들이 추가 정보를 얻을 수 있도록 합니다.
#
#
#             ---
#
#             ## SEO 권장사항
#
#             ## LangChain 시작 가이드 SEO 최적화 권장사항
#
# **분석 결과:**
#
# 전반적으로 훌륭한 초안입니다. 흥미로운 도입부와 핵심 개념을 잘 설명하고 있습니다. 하지만 SEO 관점에서 몇 가지 개선점을 적용하면 검색 엔진에서 더 높은 순위를 얻을 수 있습니다.
#
# **1. 추천 키워드 (주 키워드 + 롱테일 키워드):**
#
# *   **주 키워드:** LangChain
# *   **롱테일 키워드:**
#     *   LangChain 시작 가이드
#     *   LLM 개발 가이드
#     *   LangChain 예제
#     *   LangChain 사용법
#     *   LangChain 튜토리얼
#     *   LangChain 개발
#     *   LangChain with GPT-4 (GPT-4 관련 언급 시)
#
# **2. 메타 디스크립션 (150-160자):**
#
# "LangChain으로 LLM 애플리케이션 개발을 시작하세요! GPT-4, PaLM 등 대규모 언어 모델을 활용한 개발을 위한 완벽 가이드입니다. LangChain의 핵심 개념, 예제 코드, 사용법을 통해 LLM 개발의 장벽을 낮추고, 당신의 첫 번째 LLM 애플리케이션을 만들 수 있도록 돕습니다. 지금 바로 시작하세요!"
#
# **3. 제목 개선안 (SEO 친화적):**
#
# *   **선택 1 (핵심 키워드 강조):** LangChain 시작 가이드: LLM 개발, 예제 코드, 사용법 완벽 정리
# *   **선택 2 (호기심 유발):** LangChain으로 LLM 개발 시작하기: GPT-4, PaLM 활용 튜토리얼
# *   **선택 3 (구체적인 내용 강조):** LangChain 시작 가이드: GPT-4, PaLM을 이용한 LLM 개발 튜토리얼
#
# **4. 헤딩 구조 개선 제안:**
#
# *   H1: LangChain으로 시작하는 LLM 마법: 주니어 개발자를 위한 완벽 가이드 (제목)
# *   H2: LangChain이란 무엇인가? - LLM 개발의 핵심
# *   H3: LangChain의 핵심 구성 요소 (LLM, Chain, Agent)
# *   H2: LangChain으로 LLM 애플리케이션 만들기 - 첫 번째 예제
# *   H2: LangChain 사용법 - 데이터 연결, 프롬프트 템플릿, LLM 호출
# *   H2: LangChain 추가 기능 - 데이터베이스 연동, 외부 API 활용 (필요에 따라)
#
# **5. 내부/외부 링크 권장사항:**
#
# *   **내부 링크:** LangChain 공식 문서, LangChain 튜토리얼, LangChain 커뮤니티 링크 등
# *   **외부 링크:**
#     *   GPT-3, GPT-4, PaLM 등 LLM 공식 문서 링크
#     *   LangChain 관련 오픈 소스 프로젝트 링크 (GitHub)
#     *   LLM 개발 관련 유용한 자료 링크 (블로그, 튜토리얼 등)
#
# **추가 권장사항:**
#
# *   **키워드 밀도:** 키워드를 자연스럽게 문맥에 맞게 배치하고, 제목, 헤딩, 본문에 적절히 포함합니다.
# *   **이미지 최적화:** 이미지 파일명에 키워드를 포함하고, alt 텍스트를 추가합니다.
# *   **가독성:** 문단을 짧게 나누고, 목록(bullet point)를 사용하여 내용을 쉽게 이해하도록 돕습니다.
# *   **CTA (Call to Action):** “LangChain 시작하기”, “LangChain 튜토리얼 보기” 등 사용자가 다음 단계로 이동하도록 유도합니다.
#
# **결론:**
#
# 위의 제안사항을 적용하면 LangChain 시작 가이드의 SEO 성능을 크게 향상시킬 수 있습니다. 꾸준한 업데이트와 검색 트렌드 분석을 통해 콘텐츠를 최적화하는 것이 중요합니다.
#
#             ---
#
#             ## 제작 프로세스
#                 조사 완료 (Research Agent)
#                 초안 작성 완료 (Writer Agent)
#                 SEO 분석 완료 (SEO Agent)
#                 최종 편집 완료 (Editor Agent)

# %% [markdown]
# ### 단계별 작업 결과 확인

# %%
print("\nResearch Agent 조사 결과:")
print("-" * 80)
print(result["research_data"][:500] + "...\n")
# Out:
# Research Agent 조사 결과:
# --------------------------------------------------------------------------------
# ## 개발자를 위한 LangChain 시작 가이드: 핵심 정리
#
# **주제:** 개발자를 위한 LangChain 시작 가이드
# **타겟 독자:** Python을 다룰 줄 아는 주니어-미들 레벨 개발자
#
# **1. 핵심 개념 및 정의**
#
# * **LangChain:** LLM(Large Language Model) 기반 애플리케이션 개발을 위한 프레임워크입니다. LLM을 다양한 데이터 소스와 연결하고, 복잡한 작업을 수행하도록 안내하는 데 초점을 맞춥니다.
# * **LLM (Large Language Model):** GPT-3, GPT-4, PaLM 등 방대한 텍스트 데이터를 학습하여 텍스트를 생성, 번역, 요약, 질문 답변 등 다양한 작업을 수행할 수 있는 AI 모델입니다.
# * **Chains (체인):** LangChain의 핵심 구성 요소로, LLM과 다양한 구성 요소를 연결하여 특정 작업을 수행하는 일련의 단계를 의미합니다. 데이터 로딩, 프롬프트 템플릿, LLM 호출 등을 포함합니...

# %%
print("\nWriter Agent 초안:")
print("-" * 80)
print(result["draft_content"][:500] + "...\n")
# Out:
# Writer Agent 초안:
# --------------------------------------------------------------------------------
# ## LangChain으로 시작하는 LLM 마법: 주니어 개발자를 위한 완벽 가이드
#
# **“GPT-3만으로는 부족해! LangChain으로 LLM의 잠재력을 최대한 활용해봐!”**
#
# 안녕하세요, 여러분! 저는 여러분의 개발 여정을 돕는 블로그 작가입니다. 최근 LLM(Large Language Model) 기술이 급부상하면서, GPT-3나 GPT-4 같은 강력한 모델을 활용한 애플리케이션 개발에 대한 관심이 높아지고 있죠. 하지만, LLM만으로는 원하는 수준의 복잡한 작업을 수행하기 어려울 때가 많습니다. 바로 이럴 때 LangChain이 여러분의 개발을 돕습니다. LangChain은 LLM을 다양한 데이터 소스와 연결하고, 복잡한 작업을 수행하도록 안내하는 프레임워크입니다. 이 가이드에서는 LangChain의 핵심 개념을 쉽게 이해하고, 여러분의 첫 번째 LLM 애플리케이션을 만드는 데 필요한 정보를 제공합니다.
#
# **1. LangChain, 무엇이 다를까?**
#
# LLM은 텍스트를...

# %%
print("\nSEO Agent 권장사항:")
print("-" * 80)
print(result["seo_recommendations"][:500] + "...\n")
# Out:
# SEO Agent 권장사항:
# --------------------------------------------------------------------------------
# ## LangChain 시작 가이드 SEO 최적화 권장사항
#
# **분석 결과:**
#
# 전반적으로 훌륭한 초안입니다. 흥미로운 도입부와 핵심 개념을 잘 설명하고 있습니다. 하지만 SEO 관점에서 몇 가지 개선점을 적용하면 검색 엔진에서 더 높은 순위를 얻을 수 있습니다.
#
# **1. 추천 키워드 (주 키워드 + 롱테일 키워드):**
#
# *   **주 키워드:** LangChain
# *   **롱테일 키워드:**
#     *   LangChain 시작 가이드
#     *   LLM 개발 가이드
#     *   LangChain 예제
#     *   LangChain 사용법
#     *   LangChain 튜토리얼
#     *   LangChain 개발
#     *   LangChain with GPT-4 (GPT-4 관련 언급 시)
#
# **2. 메타 디스크립션 (150-160자):**
#
# "LangChain으로 LLM 애플리케이션 개발을 시작하세요! GPT-4, PaLM 등 대규모 언어 모델을 활용한 개발을 ...

# %%
print("\nEditor Agent 최종 편집본:")
print("-" * 80)
print(result["edited_content"][:500] + "...\n")
# Out:
# Editor Agent 최종 편집본:
# --------------------------------------------------------------------------------
# ## LangChain으로 시작하는 LLM 마법: 주니어 개발자를 위한 완벽 가이드
#
# **“GPT-4, PaLM 등 대규모 언어 모델을 활용한 개발을 위한 완벽 가이드! LangChain으로 LLM 개발의 장벽을 낮추고, 당신의 첫 번째 LLM 애플리케이션을 만들 수 있도록 돕습니다.”**
#
# 안녕하세요, 여러분! 저는 여러분의 개발 여정을 돕는 블로그 작가입니다. 최근 대규모 언어 모델(LLM) 기술, 특히 GPT-4, PaLM 등이 급부상하면서, LLM을 활용한 애플리케이션 개발에 대한 관심이 폭발적으로 증가하고 있습니다. 하지만 LLM만으로는 원하는 수준의 복잡한 작업을 수행하기 어려울 때가 많습니다. 바로 이럴 때 LangChain이 여러분의 개발을 돕습니다. LangChain은 LLM을 다양한 데이터 소스와 연결하고, 복잡한 작업을 수행하도록 안내하는 강력한 프레임워크입니다. 이 가이드에서는 LangChain의 핵심 개념을 쉽게 이해하고, 여러분의 첫 번째 LLM 애플리케이션...

# %% [markdown]
# ### [Langsmith](https://smith.langchain.com/)

# %% [markdown]
# ![image.png](attachment:image.png)
