# %% [markdown]
# # Sequential & Collaborative Agents란?
#
# **Sequential Agent**와 **Collaborative Agent**는 여러 에이전트가 함께 작업하는 Multi-Agent 패턴입니다.

# %% [markdown]
# ## Sequential Agent (순차적 에이전트)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 핵심 특징
# 1. **파이프라인 방식** (Pipeline Pattern)
#    - 에이전트들이 정해진 순서대로 실행
#    - 이전 에이전트의 출력이 다음 에이전트의 입력
#
# 2. **단계별 처리** (Step-by-Step Processing)
#    - 각 단계가 명확하게 구분됨
#    - 데이터가 단계를 거치며 변환/개선
#
# 3. **고정된 워크플로우** (Fixed Workflow)
#    - 실행 순서가 미리 정해짐
#    - 예측 가능한 흐름

# %% [markdown]
# ### 작동 방식
# ```
# 입력 → Agent A → Agent B → Agent C → 출력
#       (단계1)   (단계2)   (단계3)
# ```

# %% [markdown]
# ## Collaborative Agent (협업 에이전트)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 핵심 특징
# 1. **병렬 실행** (Parallel Execution)
#    - 여러 에이전트가 동시에 작업
#    - 서로 의존하지 않고 독립적으로 실행
#
# 2. **결과 집계** (Result Aggregation)
#    - 각 에이전트의 결과를 수집
#    - 통합 에이전트가 최종 결과 생성
#
# 3. **동등한 관계** (Equal Partnership)
#    - 계층 구조 없이 수평적 협업
#    - 각자의 전문성 발휘

# %% [markdown]
# ### 작동 방식
# ```
#         입력
#          ↓
#     ┌────┼────┐
#     ↓    ↓    ↓
# Agent A  B  C (병렬 실행)
#     ↓    ↓    ↓
#     └────┼────┘
#          ↓
#    결과 통합
#          ↓
#        출력
# ```

# %% [markdown]
# # Multi Agents - 코드 리뷰 시스템
# LangGraph를 활용하여 여러 에이전트가 병렬로 실행되고 결과를 집계하는 코드 리뷰 시스템을 구현합니다.

# %% [markdown]
# ### 이 예제가 Sequential & Collaborative Agent인 이유
#
# **코드 리뷰 시스템**은 두 패턴을 결합한 사례입니다:
#
# #### Collaborative 측면
# 1. **병렬 실행**: 4개의 리뷰 에이전트가 동시에 코드 분석
#    - 코드 분석 에이전트
#    - 버그 검사 에이전트
#    - 스타일 검사 에이전트
#    - 성능 분석 에이전트
#
# 2. **독립적 작업**: 각 에이전트가 자신의 관점에서 독립적으로 리뷰
#
# 3. **결과 집계**: 통합 리포트 에이전트가 모든 리뷰 결과를 종합
#
# #### Sequential 측면
# 1. **순차적 흐름**: 병렬 리뷰 → 결과 수집 → 통합 리포트
# 2. **단계별 처리**: 개별 분석 후 통합 단계
#
# ### 장점
#
# **Collaborative의 장점**:
# - 빠른 실행 (병렬 처리)
# - 다양한 관점 확보
# - 확장성 (에이전트 추가/제거 쉬움)
#
# **Sequential의 장점**:
# - 명확한 프로세스
# - 단계별 추적 가능
# - 순차적 개선
#
# ### vs. 다른 패턴
#
# | 패턴 | 실행 방식 | 관계 |
# |------|----------|------|
# | **Hierarchical** | 1개 선택 실행 | 계층적 |
# | **Collaborative** | 병렬 실행 | 수평적 |
# | **Sequential** | 순차 실행 | 파이프라인 |
# | **Supervisor** | 순차 조율 | 관리-피관리 |
#
# ### 적합한 사용 사례
#
# **Collaborative**:
# - 코드 리뷰 (여러 관점)
# - 문서 검토 (문법, 스타일, 내용)
# - 다각도 분석
#
# **Sequential**:
# - 데이터 처리 파이프라인
# - 문서 작성 (초안 → 검토 → 편집)
# - 단계별 승인 프로세스

# %% [markdown]
# ## 구성
# 1. **코드 분석 에이전트**: 코드 구조와 로직 파악
# 2. **버그 검사 에이전트**: 잠재적 버그와 오류 찾기
# 3. **스타일 검사 에이전트**: 코딩 컨벤션 및 스타일 확인
# 4. **성능 분석 에이전트**: 성능 이슈 및 최적화 제안
# 5. **통합 리포트 에이전트**: 모든 리뷰 결과 종합

# %% [markdown]
# ## 학습 목표
# - 병렬 실행 (parallel execution): 여러 에이전트 동시 실행
# - 결과 집계 (aggregation): 각 에이전트 결과를 모아서 처리
# - 독립적 작동: 각 에이전트가 서로 의존하지 않고 실행

# %% [markdown]
# ## 1단계: LLM 초기화

# %% [markdown]
# ### [OpenAI](https://openai.com/)
# - OpenAI는 인공지능 기술을 연구하고 세상에 공개하는 회사입니다.
# - 우리가 쓰는 ChatGPT, 이미지 만드는 DALL·E 같은 것도 OpenAI가 만든 LLM 모델들입니다.

# %% [markdown]
# - [OpenAI 가입/로그인](https://platform.openai.com/docs/overview)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - [OpenAI 결제](https://platform.openai.com/settings/organization/billing/overview)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - [OpenAI API Key 발급](https://platform.openai.com/api-keys)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from dotenv import load_dotenv

# dotenv 파일에서 환경변수 로드
load_dotenv()
# Out:
# True

# %% [markdown]
# - [OpenAI(ChatGPT) Model](https://platform.openai.com/docs/models)
# - [모델별 금액](https://platform.openai.com/docs/pricing)

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-5-nano",
    reasoning_effort="high",        # 논리성 강화
)

# %% [markdown]
# ## 2단계: 상태 정의 (State Management)
#
# 병렬 실행을 위한 상태 구조를 정의합니다. `Annotated`와 `add` 연산자를 사용하여 각 에이전트의 결과를 리스트에 집계합니다.

# %%
from typing import TypedDict, List, Annotated
from operator import add

class ReviewState(TypedDict):
    """
    코드 리뷰 시스템의 상태를 정의하는 클래스
    """
    code: str
    reviews: Annotated[List[str], add]  # add 연산자로 자동 집계
    final_report: str

# %% [markdown]
# ## 3단계: 병렬 실행 에이전트 정의
#
# 각 에이전트는 독립적으로 코드를 분석하고, 결과를 `reviews` 리스트에 추가합니다.

# %% [markdown]
# ### 코드 분석 에이전트

# %%
from langchain_core.messages import HumanMessage, SystemMessage

def code_analysis_agent(state: ReviewState) -> dict:
    """
    코드의 구조와 로직을 분석하는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 코드 구조 분석 전문가입니다.
            다음 관점에서 코드를 분석하세요:
            - 전체적인 구조와 설계 패턴
            - 함수/클래스의 역할과 책임
            - 코드의 가독성과 유지보수성
            - 모듈화 수준

            간결하고 명확하게 분석 결과를 제공하세요."""),
        HumanMessage(content=f"다음 코드를 분석하세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[코드 구조 분석]\n{response.content}"
    
    print("[코드 분석 에이전트] 분석 완료")
    
    return {
        "reviews": [review]  # 리스트로 반환하여 자동 집계
    }

# %% [markdown]
# ### 버그 검사 에이전트

# %%
def bug_detection_agent(state: ReviewState) -> dict:
    """
    잠재적 버그와 오류를 찾는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 버그 탐지 전문가입니다.
            다음 관점에서 코드를 검사하세요:
            - 논리적 오류 가능성
            - 예외 처리 누락
            - Null/Undefined 참조 위험
            - 경계 조건 처리
            - 리소스 누수 가능성

            발견된 문제와 해결 방안을 제시하세요."""),
        HumanMessage(content=f"다음 코드에서 버그를 찾으세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[버그 검사]\n{response.content}"
    
    print("[버그 검사 에이전트] 검사 완료")
    
    return {
        "reviews": [review]
    }

# %% [markdown]
# ### 스타일 검사 에이전트

# %%
def style_check_agent(state: ReviewState) -> dict:
    """
    코딩 컨벤션과 스타일을 검사하는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 코딩 스타일 전문가입니다.
            다음 관점에서 코드를 검사하세요:
            - 네이밍 컨벤션 (변수, 함수, 클래스명)
            - 코드 포맷팅 (들여쓰기, 줄바꿈)
            - 주석의 적절성
            - 코드 일관성
            - 베스트 프랙티스 준수 여부

            개선 사항을 구체적으로 제안하세요."""),
        HumanMessage(content=f"다음 코드의 스타일을 검사하세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[스타일 검사]\n{response.content}"
    
    print("[스타일 검사 에이전트] 검사 완료")
    
    return {
        "reviews": [review]
    }

# %% [markdown]
# ### 성능 분석 에이전트

# %%
def performance_analysis_agent(state: ReviewState) -> dict:
    """
    성능 이슈를 분석하고 최적화 방안을 제안하는 에이전트
    """
    code = state["code"]
    
    messages = [
        SystemMessage(content="""
            당신은 성능 최적화 전문가입니다.
            다음 관점에서 코드를 분석하세요:
            - 시간 복잡도와 공간 복잡도
            - 불필요한 연산이나 중복 코드
            - 메모리 사용 효율성
            - 알고리즘 최적화 가능성
            - 병목 지점

            구체적인 최적화 방안을 제시하세요."""),
        HumanMessage(content=f"다음 코드의 성능을 분석하세요:\n\n{code}")
    ]
    
    response = llm.invoke(messages)
    review = f"[성능 분석]\n{response.content}"
    
    print("[성능 분석 에이전트] 분석 완료")
    
    return {
        "reviews": [review]
    }

# %% [markdown]
# ## 4단계: 결과 집계 에이전트
#
# 모든 병렬 에이전트의 결과를 받아 통합 리포트를 생성합니다.

# %%
def aggregation_agent(state: ReviewState) -> dict:
    """
    모든 리뷰 결과를 종합하여 최종 리포트를 생성하는 에이전트
    """
    reviews = state["reviews"]
    
    # 모든 리뷰 결과를 하나의 문자열로 결합
    all_reviews = "\n\n".join(reviews)
    
    messages = [
        SystemMessage(content="""
            당신은 시니어 코드 리뷰어입니다.
            여러 전문가들의 리뷰 결과를 받았습니다. 이를 종합하여:
            1. 주요 발견 사항 요약
            2. 우선순위별 개선 사항 정리
            3. 전체적인 코드 품질 평가
            4. 구체적인 액션 아이템 제시

            명확하고 실행 가능한 최종 리포트를 작성하세요."""),
        HumanMessage(content=f"""
            다음은 각 전문가들의 리뷰입니다:
            
            {all_reviews}
            
            이를 종합하여 최종 리포트를 작성하세요.""")
    ]
    
    response = llm.invoke(messages)
    final_report = response.content
    
    print("[통합 리포트 에이전트] 최종 리포트 생성 완료")
    
    return {
        "final_report": final_report
    }

# %% [markdown]
# ## 5단계: 그래프 구성 (병렬 실행)
#
# 여러 에이전트가 동시에 실행되도록 그래프를 구성합니다.
#
# ### 그래프 구조
# ```
#                     시작
#                      |
#                      v
#          +-----------+-----------+-----------+
#          |           |           |           |
#          v           v           v           v
#   코드 분석    버그 검사    스타일 검사     성능 분석
#          |           |           |           |
#          +-----+-----+-----------+-----------+
#                |           |
#                v           v
#           통합 리포트   (병렬 실행)
#                |
#                v
#               종료
# ```

# %%
from langgraph.graph import StateGraph, END

# StateGraph 생성
workflow = StateGraph(ReviewState)

# 병렬 실행될 노드들 추가
workflow.add_node("code_analysis", code_analysis_agent)
workflow.add_node("bug_detection", bug_detection_agent)
workflow.add_node("style_check", style_check_agent)
workflow.add_node("performance_analysis", performance_analysis_agent)

# 결과 집계 노드 추가
workflow.add_node("aggregation", aggregation_agent)

# 시작점 설정 - 4개의 에이전트로 동시 분기
workflow.set_entry_point("code_analysis")
workflow.set_entry_point("bug_detection")
workflow.set_entry_point("style_check")
workflow.set_entry_point("performance_analysis")

# 모든 병렬 에이전트에서 집계 에이전트로 연결
workflow.add_edge("code_analysis", "aggregation")
workflow.add_edge("bug_detection", "aggregation")
workflow.add_edge("style_check", "aggregation")
workflow.add_edge("performance_analysis", "aggregation")

# 집계 에이전트에서 종료
workflow.add_edge("aggregation", END)

# 그래프 컴파일
app = workflow.compile()

# %% [markdown]
# ## 6단계: 그래프 시각화 (선택사항)

# %%
from IPython.display import Image, display

try:
    
    display(
        Image(
            app.get_graph().draw_mermaid_png(max_retries=5, retry_delay=2.0)
        )
    )
except Exception as e:
    print(f"그래프 표시 오류: {e}")

# %% [markdown]
# ## 7단계: 테스트 예제
#
# 실제 코드를 리뷰하는 예제입니다.

# %% [markdown]
# ### 테스트 코드 준비

# %%
# 리뷰할 샘플 코드 (의도적으로 개선 여지가 있는 코드)
sample_code = """
def find_duplicates(list):
    result = []
    for i in range(len(list)):
        for j in range(len(list)):
            if i != j and list[i] == list[j]:
                if list[i] not in result:
                    result.append(list[i])
    return result

def calculate_average(numbers):
    sum = 0
    for n in numbers:
        sum = sum + n
    avg = sum / len(numbers)
    return avg

class userManager:
    def __init__(self):
        self.users = []
    
    def add_user(self, name, age):
        self.users.append({'name': name, 'age': age})
    
    def get_user(self, name):
        for user in self.users:
            if user['name'] == name:
                return user
        return None
"""

print("샘플 코드가 준비되었습니다.")
# Out:
# 샘플 코드가 준비되었습니다.

# %% [markdown]
# ### 코드 리뷰 실행

# %%
# 초기 상태 생성
initial_state = {
    "code": sample_code
}

# 그래프 실행 (병렬 실행)
result = app.invoke(initial_state)
# Out:
# [스타일 검사 에이전트] 검사 완료
# [코드 분석 에이전트] 분석 완료
# [버그 검사 에이전트] 검사 완료
# [성능 분석 에이전트] 분석 완료
# [통합 리포트 에이전트] 최종 리포트 생성 완료

# %% [markdown]
# ### 개별 리뷰 결과 확인

# %%
for i, review in enumerate(result["reviews"], 1):
    print(f"\n리뷰 {i}:")
    print("-" * 80)
    print(review)
    print()
# Out:
# 리뷰 1:
# --------------------------------------------------------------------------------
# [버그 검사]
# 다음 코드에서 버그와 개선점들을 찾아서 제시합니다. 각 항목마다 원인과 제안하는 해결 방안을 함께 적었습니다.
#
# 1) find_duplicates(list)
#
# 문제점 요약
# - 매개변수 이름으로 list를 사용하면 파이썬의 내장 타입 이름을 그림자(오버라이드)합니다. 이는 가독성과 유지보수에 악영향을 줄 수 있습니다.
# - 입력이 None인 경우 예외 처리가 없어 바로 TypeError가 발생합니다.Null/undefined 참조 위험이 존재합니다.
# - 시간복잡도가 O(n^2)로 비효율적입니다. 큰 입력에 대해 느립니다.
# - NaN과 같은 특수한 값 처리 문제: NaN은 자체적으로 NaN과 같지 않으므로, 리스트에 NaN이 두 개 이상 있어도 중복으로 인식되지 않을 수 있습니다.
# - 중복 목록의 순서를 항상 보장하는지에 대한 명확한 의도가 불분명합니다. (현재 방식은 발견 순서대로 담길 수 있습니다.)
#
# 개선 및 해결 방안
# - 매개변수 이름을 items 등으로 바꿔 내장 타입과의 혼동 방지.
# - None 입력에 대한 검사 추가.
# - 효율성 개선(해시 기반 집합으로 중복 탐지) 또는 최소한 중복 탐지 루프를 절반으로 줄이는 방식 도입.
# - NaN 처리에 대한 옵션 고려. 필요 시 NaN도 중복으로 간주하도록 특수 처리 추가.
#
# 권장 수정 예시 1(간단하고 안전한 버전, 해시 가능한 아이템에 대해 빠르게 중복 탐지)
# - 아이템이 해시 가능(hashable)인 경우에 빠르게 동작합니다.
# - None 입력에 대한 체크를 추가합니다.
# - 이름 충돌 방지 및 가독성 향상.
#
# def find_duplicates(items):
#     if items is None:
#         raise TypeError("items must not be None")
#     duplicates = []
#     seen = set()
#     for item in items:
#         try:
#             if item in seen:
#                 if item not in duplicates:
#                     duplicates.append(item)
#             else:
#                 seen.add(item)
#         except TypeError:
#             # 아이템이 해시 불가능한 경우
#             if item in duplicates:
#                 continue
#             # 해시 불가능한 item은 선형 탐색으로 중복 여부 판단
#             if any(item == d for d in duplicates):
#                 if item not in duplicates:
#                     duplicates.append(item)
#             else:
#                 duplicates.append(item)
#     return duplicates
#
# 권장 수정 예시 2(더 단순하게, 중복 탐지 루프를 절반으로 줄임)
# def find_duplicates(items):
#     if items is None:
#         raise TypeError("items must not be None")
#     duplicates = []
#     for i in range(len(items)):
#         for j in range(i + 1, len(items)):
#             if items[i] == items[j] and items[i] not in duplicates:
#                 duplicates.append(items[i])
#     return duplicates
#
# 참고
# - NaN을 중복으로 간주하려면 추가 특수 케이스가 필요합니다. 예를 들어 math.isnan를 이용해 NaN끼리는 중복으로 간주하도록 조건을 보완할 수 있습니다.
#
# 2) calculate_average(numbers)
#
# 문제점 요약
# - sum이라는 이름의 로컬 변수를 사용하여 내장 함수 sum를 그림자화합니다. 이로 인해 같은 스코프에서 sum을 호출하면 의도치 않은 동작이나 오류가 발생할 수 있습니다.
# - 빈 시퀀스일 때나 None 입력일 때 0으로 나누는 경우가 발생할 수 있어 예외가 발생합니다( division by zero).
# - 입력 검증이 부족합니다. None이나 비정렬 가능 객체가 들어올 수 있습니다.
#
# 개선 및 해결 방안
# - sum 변수 이름을 total 등으로 바꿔 내장 함수 그림자화를 피합니다.
# - 빈 입력에 대해 예외를 명시적으로 처리합니다.
# - 필요 시 예외를 명시적으로 raise하고, 비숫자형 타입 입력에 대한 타입 검사도 추가합니다.
#
# 권장 수정 예시
# def calculate_average(numbers):
#     if numbers is None:
#         raise TypeError("numbers must not be None")
#     if len(numbers) == 0:
#         raise ValueError("cannot compute average of empty sequence")
#     total = 0
#     for n in numbers:
#         total += n
#     return total / len(numbers)
#
# 또는 더 간단하게(내장 sum 사용, 숫자 시퀀스 전제 시)
#
# def calculate_average(numbers):
#     if not numbers:
#         raise ValueError("numbers must be non-empty")
#     return sum(numbers) / len(numbers)
#
# 주의사항
# - 위 두 버전 중 하나를 채택하면 sum이 로컬 변수로 그림자지는 문제가 제거됩니다. 다만 numbers에 비숫자 타입이 들어오면 TypeError가 발생하므로 필요 시 타입 검사도 추가하십시오.
#
# 3) class userManager
#
# 문제점 요약
# - 클래스 이름이 PEP8 스타일(대문자 카멜케이스)과 다릅니다. 보통 UserManager로 표기합니다.
# - get_user가 내부의 실제 딕셔너리 객체를 반환합니다. 반환된 객체를 외부에서 수정하면 내부 상태가 바뀔 수 있어 데이터 무결성에 위험이 있습니다.
# - add_user에 대한 입력 검증이 없습니다. 이름이나 나이가 잘못된 타입/값일 수 있습니다.
# - 스레드 안전성이나 동시성 문제를 고려하지 않았습니다. 다중 스레드 환경에서의 안전성은 보장되지 않습니다.
#
# 개선 및 해결 방안
# - 클래스 이름과 메서드에 대한 타입 힌트/문서화를 추가하고, 가독성을 높입니다.
# - get_user는 내부 객체의 얕은 복사본을 반환하도록 수정합니다.
# - add_user에 입력 검증을 추가합니다(예: name은 문자열, age는 음이 아닌 정수).
# - 필요 시 remove_user, update_user 같은 관리 기능 추가를 고려합니다.
# - 가능하면 dataclass를 사용해 사용자 데이터를 구조화합니다.
#
# 권장 수정 예시
# class UserManager:
#     def __init__(self):
#         self.users = []
#
#     def add_user(self, name, age):
#         if not isinstance(name, str) or not name:
#             raise ValueError("name must be a non-empty string")
#         if not isinstance(age, int) or age < 0:
#             raise ValueError("age must be a non-negative integer")
#         self.users.append({'name': name, 'age': age})
#
#     def get_user(self, name):
#         for user in self.users:
#             if user['name'] == name:
#                 return dict(user)  # 얕은 복사본 반환
#         return None
#
# 추가 권장사항
# - 현재 코드에 대해 타입 힌트를 추가하고, PEP8에 맞춰 네이밍과 포맷을 정리하는 것을 권장합니다.
# - 각 함수/메서드에 간단한 docstring을 추가하면 의도와 사용법이 더 명확해집니다.
# - 입력에 대한 예외를 명시적으로 처리하고, 가능하면 단위 테스트를 추가해 경계 조건을 확인하십시오(예: 빈 입력, None 입력, 잘못된 타입 등).
# - 필요에 따라 로깅을 추가해 버그를 추적하기 쉽게 만드십시오.
#
# 요약
# - find_duplicates: 매개변수 이름 정리, None 입력 체크, NaN 처리 옵션 고려, 효율성 개선.
# - calculate_average: sum의 그림자화 제거, 빈 입력 예외 처리, 입력 타입 체크.
# - class userManager: 네이밍 수정, get_user의 반환값 복사, 입력 검증 추가, 가능하면 확장성/타입 힌트 추가.
#
# 필요하시면 위의 각 수정 예시를 바탕으로 실제 테스트 코드도 함께 제공해 드리겠습니다.
#
#
# 리뷰 2:
# --------------------------------------------------------------------------------
# [코드 구조 분석]
# 다음 코드를 간단히 분석하고, 개선점을 제안합니다.
#
# 요약
# - 코드 구조는 두 개의 독립적인 유틸리티 함수와 하나의 간단한 관리 클래스로 구성되어 있습니다.
# - 전반적으로 기능 분리는 되어 있지만 Python 컨벤션, 에러 처리, 타입 힌트 등이 부족합니다.
# - 성능 면에서 find_duplicates는 이중 루프(O(n^2))로 구현되어 있어 대규모 입력에서 비효율적입니다. calculate_average도 내장 함수 사용 및 예외 처리 측면에서 개선 여지가 있습니다.
# - userManager의 네이밍/구조는 파이썬의 일반적인 스타일(Pep8)과 데이터 모델링 관점에서 보완이 필요합니다.
#
# 1) 전체 구조와 설계 패턴
# - 구분: find_duplicates와 calculate_average는 순수한 함수형 유틸리티이고, userManager는 간단한 상태를 가진 클래스입니다.
# - 의존성/모듈화: 세 가지 구성요소가 서로 독립적이지만, 모듈화 수준은 낮아 보입니다. 하나의 파일에 모두 들어 있어 재사용보다는 간단한 샘플 용도로 보입니다.
# - 설계 패턴 측면: 간단한 '저장소(component) + 조작 메서드' 패턴이지만, 저장소의 구현이 리스트 + 딕셔너리 구조로 비정형적입니다. 엄밀한 도메인 모델이나 인터페이스 계층은 없습니다.
#
# 2) 함수/클래스의 역할과 책임
# - find_duplicates(list)
#   - 역할: 리스트 내에서 중복되는 값을 찾아 중복값을 하나씩만 담은 리스트로 반환.
#   - 구현 특징: 이중 루프(i, j)로 비교. i != j 조건으로 자기 자신과 비교를 피하고, 중복 발견 시 result에 이미 있으면 중복 추가하지 않도록 guard가 있습니다.
#   - 문제점/리스크: 매개변수 이름으로 'list'를 사용하고 있는데 이는 파이썬의 내장 타입 이름을 가려버리는 습관으로 바람직하지 않습니다. 시간복잡도 O(n^2)으로 비효율적이고, 입력에 따라 unhashable 요소가 있을 경우 다른 구현으로 바꿔야 할지가 문제될 수 있습니다.
# - calculate_average(numbers)
#   - 역할: 숫자 시퀀스의 산술 평균을 반환.
#   - 구현 특징: 합계를 수동으로 누적하고 len(numbers)로 평균을 구합니다.
#   - 문제점/리스크: sum이라는 변수 이름이 파이썬의 내장 함수 sum을 가려버립니다. 또한 빈 시퀀스에 대해 나눗셈이 발생해 ZeroDivisionError가 납니다. 입력 타입에 대한 검증도 없습니다.
# - class userManager
#   - 역할: 이름/나이 정보를 가진 사용자를 메모리 영역에 저장하고 조회하는 간단한 관리 객체.
#   - 구현 특징: self.users를 리스트로 두고, add_user는 이름/나이를 딕셔너리로 저장, get_user는 이름으로 검색해 해당 사용자 dict를 반환합니다.
#   - 문제점/리스크: 네이밍이 파이썬 컨벤션(Pep8)에 어긋납니다. 클래스 이름은 UserManager가 일반적이며, 저장 자료구조도 리스트의 딕셔너리 형태로 다루는 것이 유지보수에 좋지 않습니다. 동일 이름의 사용자를 중복 저장/검색하는 정책이 명확하지 않습니다. 타입 힌트, 예외처리, 문서화가 부족합니다.
#
# 3) 가독성 및 유지보수성
# - 가독성
#   - 변수명과 매개변수 이름에 대한 일관성 부족: list, sum 같은 파이썬 내장 이름을 피해야 합니다.
#   - 타입 힌트나 문서 문자열(docstrings)이 없어 의도와 사용법 파악이 어렵습니다.
#   - 파이썬 코딩 컨벤션(Pep8)으로부터 벗어난 클래스 네이밍, 메서드 네이밍 등이 있습니다.
# - 유지보수성
#   - 예외처리 부재: calculate_average는 빈 입력에 대한 처리, find_duplicates는 다양한 입력 타입에 대한 방어 코드가 부족합니다.
#   - 모듈화 부족: 세 구성요소가 서로 독립적이지만, 더 큰 시스템으로 확장하기엔 구조가 단순하고 직관적이지 않습니다.
#   - 데이터 모델링 부재: 사용자 데이터를 딕셔너리 리스트로만 다루는데, 규모가 커지면 타입 안전성과 검색 성능이 문제될 수 있습니다.
#
# 4) 모듈화 수준
# - 현재 코드는 하나의 파일에 세 가지 기능이 모여 있습니다. 작은 예제에는 무리가 없지만 real-world 프로젝트에서는 모듈/패키지로 분리하고, 데이터 모델(User)와 저장소(Storage/Repository) 계층을 분리하는 것이 좋습니다.
# - 권장 구조 예시
#   - models.py: User 데이터 모델(추천: dataclass)
#   - repositories.py: UserRepository 구현(메모리 저장소, 필요한 경우 DB 저장소 인터페이스)
#   - utils.py: find_duplicates, calculate_average 같은 일반 유틸 함수
#   - services.py: UserManager 같은 서비스/도메인 로직
#   - tests/ 폴더로 단위 테스트 추가
#
# 개선 제안(구체적 방향)
# - 공통 개선
#   - 코드 스타일: 클래스 이름은 UserManager, 함수/메서드 이름은 snake_case로 유지. 예: add_user, get_user.
#   - 타입 힌트: 함수 시그니처에 타입 힌트를 추가하고, 가능하면 Optional 반환 타입도 명시.
#   - docstrings: 각 함수/메서드에 간단한 설명 추가.
#   - 빈 입력/에러 케이스에 대한 방어 코드 추가.
#   - 저장소 구조 결정: 중복 이름 허용 여부에 따라 저장소 구조를 결정하고 선택적으로 예외를 던지도록 설계.
# - find_duplicates 개선 아이디어
#   - 아이디어 A: 단일 패스로 중복을 찾고 중복값만 수집
#     - 장점: O(n) 평균 시간 복잡도, 입력 순서를 어느 정도 보존 가능
#     - 단점: 해시 가능한 값에 한정될 수 있음(세트 활용 시)
#     - 예시(간결한 버전):
#       - 확장 버전 1(순서 보존, 중복 한 번만):
#         def find_duplicates(values):
#             seen = set()
#             duplicates = []
#             duplicates_set = set()
#             for v in values:
#                 if v in seen:
#                     if v not in duplicates_set:
#                         duplicates.append(v)
#                         duplicates_set.add(v)
#                 else:
#                     seen.add(v)
#             return duplicates
#       - 확장 버전 2(해시 가능 타입에 한정, Counter 활용):
#         from collections import Counter
#         def find_duplicates(values):
#             counts = Counter(values)
#             seen = set()
#             duplicates = []
#             for v in values:
#                 if counts[v] > 1 and v not in seen:
#                     duplicates.append(v)
#                     seen.add(v)
#             return duplicates
#   - 아이디어 B: 해시 가능 여부에 따라 다르게 구현(일반 유닛 테스트를 위한 안전한 기본 구현으로)
#     - 해시 불가능한 타입이 입력으로 올 가능성이 있다면, 이중 루프 버전이나 리스트 검색 버전으로 구현해야 합니다.
#   - 현재 구현의 한계에 따라 선택적으로 버전을 바꿔야 합니다. 주로 값의 해시 가능 여부에 따라 달라집니다.
# - calculate_average 개선 아이디어
#   - 예외 처리: 입력이 비어있거나 None인 경우를 처리하고 적절한 에러를 던지도록 한다.
#   - 내장 함수 활용: sum(numbers)와 len(numbers)를 사용하는 간단하고 빠른 구현으로 대체.
#   - 타입 힌트 및 입력 검증 추가
#   - 예시:
#     def calculate_average(numbers: list[float] | tuple[float, ...]) -> float:
#         if not numbers:
#             raise ValueError("numbers must not be empty")
#         return sum(numbers) / len(numbers)
# - userManager 개선 아이디어
#   - 네이밍 컨벤션 준수: class UserManager로 변경.
#   - 데이터 모델 도입: User 데이터 모델을 도입해 구조화하고, 검색/추가 로직을 명확히 한다.
#   - 저장소 선택:
#     - 옵션 1: 이름을 키로 한 딕셔너리 저장 (중복 이름 불가 정책이 맞다면 권장)
#       - 예시:
#         from dataclasses import dataclass
#         @dataclass
#         class User:
#             name: str
#             age: int
#
#         class UserManager:
#             def __init__(self) -> None:
#                 self.users: dict[str, User] = {}
#
#             def add_user(self, name: str, age: int) -> None:
#                 if name in self.users:
#                     raise ValueError(f"User with name {name} already exists")
#                 self.users[name] = User(name, age)
#
#             def get_user(self, name: str) -> User | None:
#                 return self.users.get(name)
#     - 옵션 2: 중복 이름 허용 필요 시, 리스트로 저장하고 검색 로직을 이름으로 순회
#       - 예시:
#         from dataclasses import dataclass
#         @dataclass
#         class User:
#             name: str
#             age: int
#
#         class UserManager:
#             def __init__(self) -> None:
#                 self.users: list[User] = []
#
#             def add_user(self, name: str, age: int) -> None:
#                 self.users.append(User(name, age))
#
#             def get_user(self, name: str) -> User | None:
#                 for user in self.users:
#                     if user.name == name:
#                         return user
#                 return None
#   - 추가 기능 권장: 목록 조회(list_users), 삭제(remove_user_by_name), 업데이트(update_user) 등 도메인 기능 확장.
#   - 타입 힌트, docstrings, 예외처리, 간단한 단위 테스트 추가.
#
# 실용적인 예시 개선 코드 요약
# - find_duplicates (개선 예시 1: 순서를 어느 정도 보존하며 중복 하나만 수집)
#   def find_duplicates(values):
#       seen = set()
#       duplicates = []
#       duplicates_set = set()
#       for v in values:
#           if v in seen:
#               if v not in duplicates_set:
#                   duplicates.append(v)
#                   duplicates_set.add(v)
#           else:
#               seen.add(v)
#       return duplicates
# - calculate_average (개선 예시)
#   def calculate_average(numbers):
#       if not numbers:
#           raise ValueError("numbers must not be empty")
#       return sum(numbers) / len(numbers)
# - UserManager (개선 예시, 파이썬 스타일)
#   from dataclasses import dataclass
#
#   @dataclass
#   class User:
#       name: str
#       age: int
#
#   class UserManager:
#       def __init__(self) -> None:
#           self.users: dict[str, User] = {}
#
#       def add_user(self, name: str, age: int) -> None:
#           if name in self.users:
#               raise ValueError(f"User with name {name} already exists")
#           self.users[name] = User(name, age)
#
#       def get_user(self, name: str) -> User | None:
#           return self.users.get(name)
#
# 이상으로, 현재 코드는 학습용으로는 충분하지만 실제 개발에선 위와 같은 개선을 통해 가독성, 확장성, 안정성을 크게 높일 수 있습니다. 필요 시 목표에 맞춰 모듈화하고, 타입 힌트와 문서화를 추가하는 것을 권합니다.
#
#
# 리뷰 3:
# --------------------------------------------------------------------------------
# [성능 분석]
# 다음 코드를 성능 측면에서 분석하고, 구체적인 최적화안을 제시합니다.
#
# 1) find_duplicates(list)
#
# 분석
# - 현재 구현:
#   - 이중 for 루프를 사용해 모든 (i, j) 쌍을 비교합니다. 따라서 시간 복잡도는 최악의 경우 O(n^2)입니다.
#   - 중복 여부를 판단한 뒤 result에 추가할 때도 매번 list 안에 있는지 검사하므로 추가 연산이 있습니다. 결과의 크기가 커질수록 추가 비용이 증가합니다.
#   - 변수 이름이 list로 되어 있어 파이썬의 내장 함수 리스트(list)와 이름이 충돌할 수 있습니다(비권장).
# - 메모리/공간 복잡도:
#   - result의 크기는 중복 원소의 수에 비례합니다. 최악의 경우 O(n) 공간이 필요합니다(중복 원소가 많을 때).
# - 병목 지점:
#   - 이중 루프 자체가 가장 큰 병목입니다. 또한 result에 매번 원소가 있는지 검사하는 부분도 비용이 큽니다.
# - 최적화 가능성:
#   - 해시 기반 방법으로 한 번의 순회로 중복 여부를 결정하면 시간 복잡도를 크게 개선할 수 있습니다. 입력 원소가 해시 가능하다는 전제하에 O(n) 시간으로 처리 가능.
#   - 중복 원소의 등장 순서를 유지하고자 한다면 두 단계로 처리하는 방식이 안전합니다.
#
# 구체적 최적화 방안
# - 방법 A: 카운트 기반(해시맵)으로 빠르게 중복 판별
#   - 코드 예시:
#     - arr를 입력으로 받되, 이름대로 arr로 표기하고, 해시 가능 자료형에 대해 동작합니다.
#     - 시간: O(n), 공간: O(n)
#     - 구현:
#       def find_duplicates(arr):
#           counts = {}
#           for x in arr:
#               counts[x] = counts.get(x, 0) + 1
#           return [x for x, c in counts.items() if c > 1]
#   - 특징: 작성이 간단하고 일반적으로 매우 빠릅니다. 중복의 순서를 보장하지는 않지만 대부분의 경우 충분합니다.
# - 방법 B: 한 번의 순회로 중복을 발견하고, 순서를 유지하는 방식
#   - 코드 예시:
#     - arr를 한 번 순회해_seen_와 _duplicates_를 구축한 뒤, 두 번째 순회에서 중복으로 확정된 값만 처음 등장 순서대로 추출합니다.
#     def find_duplicates(arr):
#         seen = set()
#         duplicates = set()
#         for x in arr:
#             if x in seen:
#                 duplicates.add(x)
#             else:
#                 seen.add(x)
#         result = []
#         added = set()
#         for x in arr:
#             if x in duplicates and x not in added:
#                 result.append(x)
#                 added.add(x)
#         return result
#   - 특징: 시간 O(n), 공간 O(n)이며, 입력 순서를 보존합니다. 중복 원소가 많아도 각 원소에 대해 한 번씩만 추가되므로 효율적입니다.
# - 방법 C: 입력을 정렬하고 인접 중복을 찾는 방식
#   - 코드 예시:
#     - arr를 정렬한 뒤 인접 원소를 비교합니다.
#     - 시간: O(n log n), 공간: O(1) (제자리 정렬의 경우)
#     def find_duplicates_sorted(arr):
#         a = sorted(arr)
#         res = []
#         for i in range(1, len(a)):
#             if a[i] == a[i - 1] and (not res or res[-1] != a[i]):
#                 res.append(a[i])
#         return res
#   - 특징: 해시를 사용하지 못하는 경우나, 메모리 제약이 매우 빡빡한 경우에 고려할 수 있습니다. 다만 원소의 원래 순서를 보존하지 못합니다.
#
# 추가 노트
# - 변수명: list 대신 arr, data, items 같은 명확한 이름 사용 권장.
# - 입력 원소가 해시 불가능한 타입(예: 리스트)을 포함하는 경우 방법 A, B의 해시 기반 접근은 실패합니다. 이 경우 방법 C나 제2의 커스텀 비교 로직을 고려해야 합니다.
#
# 2) calculate_average(numbers)
#
# 분석
# - 현재 구현:
#   - sum 변수를 수동으로 누적하고, len(numbers)로 나눕니다.
#   - 시간 복잡도: O(n) (numbers를 한 번 순회).
#   - 공간 복잡도: O(1) 추가 메모리.
#   - 문제점:
#     - sum라는 이름이 파이썬 내장 sum 함수와 겹치므로 혼동을 초래할 수 있습니다.
#     - 숫자가 비어 있는 경우(빈 시퀀스) 나눗셈이 잘못될 수 있습니다.
#     - numbers가 제네레이터나 길이가 고정되지 않는 이터레이터인 경우 len(numbers) 호출이 불가합니다.
# - 최적화 가능성:
#   - 파이썬의 내장 sum을 사용하면 C로 구현된 빠른 합계를 활용할 수 있어 속도가 더 빠릅니다.
#   - 빈 입력 처리와 제네레이터 호환성을 고려하면 더 robust합니다.
#
# 구체적 최적화 방안
# - 방법 A: 일반적인 리스트/시퀀스에 대해 빠르게 계산
#   - 코드 예시:
#     def calculate_average(numbers):
#         if not numbers:
#             return 0  # 또는 raise ValueError
#         return sum(numbers) / len(numbers)
# - 방법 B: 일반 이터러블에 대해 안정적으로 동작하도록 작성
#   - 코드 예시:
#     def calculate_average(iterable):
#         total = 0
#         count = 0
#         for x in iterable:
#             total += x
#             count += 1
#         return total / count if count else 0
#   - 특징: 입력 크기에 상관없이 한 번만 순회합니다. len(...)이 필요 없고, 제네레이터도 안전하게 처리합니다.
# - 주의점
#   - 숫자 타입이 큰 경우 누적 합에서의 오버플로우 가능성은 언어 차원의 문제이며 파이썬은 큰 정수도 다룰 수 있습니다.
#
# 3) class userManager
#
# 분석
# - 현재 구현:
#   - 데이터를 self.users에 리스트로 저장하고, 이름으로 검색하는 get_user는 리스트를 앞에서부터 순회합니다. 시간 복잡도는 O(n)입니다.
#   - add_user는 평균적으로 O(1)로 보이나, get_user의 비용이 많이 큽니다.
#   - 파이썬 명명 규칙(Pep8)상 클래스는 UserManager처럼 CamelCase로 작성하는 것이 일반적입니다.
# - 성능상 병목 지점:
#   - 다수의 조회가 필요한 상황에서 매번 선형 탐색이 병목이 됩니다.
# - 최적화 가능성:
#   - 이름으로 빠르게 조회할 수 있도록 인덱스(해시 맵)를 도입하면 get_user를 평균 O(1)로 만듭니다. 다중 사용자가 같은 이름을 가질 수 있는지 여부에 따라 구현 방식이 달라집니다.
#
# 구체적 최적화 방안
# - 방법 A: 이름을 키로 하는 인덱스 맵 추가(단일 사용자 반환 시)
#   - 코드 예시(기본적이고 간단한 버전, 중복 이름이 없다고 가정):
#     class UserManager:
#         def __init__(self):
#             self.users = []
#             self.index_by_name = {}
#
#         def add_user(self, name, age):
#             self.users.append({'name': name, 'age': age})
#             if name not in self.index_by_name:
#                 self.index_by_name[name] = len(self.users) - 1
#
#         def get_user(self, name):
#             idx = self.index_by_name.get(name)
#             if idx is None:
#                 return None
#             return self.users[idx]
#   - 시간/공간 복잡도:
#     - add_user: 평균 O(1)
#     - get_user: 평균 O(1)
#     - 공간: O(n)
#   - 주의: 같은 이름의 사용자가 여러 명일 경우 원래 동작과 차이가 납니다. 이 경우 이름당 첫 번째 사용자를 반환하는 방식으로 동작하고, 모든 사용자를 조회하려면 다른 구조가 필요합니다.
#
# - 방법 B: 중복 이름을 허용하되 이름당 여러 사용자를 저장하고, get_user가 첫 번째를 반환하도록 유지하고 싶다면
#   - 코드 예시:
#     class UserManager:
#         def __init__(self):
#             self.users = []
#             self.index_by_name = {}
#
#         def add_user(self, name, age):
#             self.users.append({'name': name, 'age': age})
#             self.index_by_name.setdefault(name, []).append(len(self.users) - 1)
#
#         def get_user(self, name):
#             idxs = self.index_by_name.get(name)
#             if not idxs:
#                 return None
#             return self.users[idxs[0]]  # 첫 번째 매칭 사용자를 반환
#   - 시간/공간 복잡도:
#     - add_user: 평균 O(1) + 추가 리스트 저장으로 O(k)에서 k는 이름의 등장 횟수
#     - get_user: O(1) 평균
#     - 공간: O(n)
#
# - 방법 C: 모든 중복 이름에 대해 모든 사용자를 조회해야 한다면, 단순히 dict[name] -> list[user] 형태로 유지하는 것도 좋습니다.
#
# 일반 최적화 팁
# - 네이밍 규칙: 함수/변수 이름은 snake_case로, 클래스는 CamelCase로 작성(Pep8 준수).
# - 불필요한 연산 제거: find_duplicates의 이중 루프 제거, sum의 사용 등.
# - 입력 형태에 따른 안정성: calculate_average는 제네레이터/이터레이터도 안전하게 작동하도록 고려할 것.
# - 데이터 구조 선택의 트레이드오프: 속도 vs 메모리 사용; 중복 여부에 따라 해시 기반 접근이 큰 이점을 제공합니다. 다만 해시 기반 접근은 해시 가능한 타입에 한정됩니다.
# - 타입 힌트와 문서화: 무엇을 반환하는지, 입력에 어떤 제약이 있는지 명확히 하여 잘못된 사용을 예방합니다.
#
# 요약
# - find_duplicates: 현재는 O(n^2) 시간, O(n) 공간. 해시 기반 구현으로 크게 속도 향상 가능. 순서를 보존하려면 추가 로직이 필요.
# - calculate_average: 현재 구현보다 파이썬 내장 sum을 활용하면 속도 향상. 제네레이터도 처리 가능하도록 두 가지 버전 제시.
# - userManager: get_user를 O(1)으로 만들 수 있는 인덱스 맵 도입 권장. 중복 이름 처리 여부에 따라 구현 방식이 달라짐. Pep8에 맞춘 명명과 선택적 데이터구조 설계 권장.
#
# 필요하다면 각 제안의 성능 비교표(시간 복잡도/공간 복잡도)와 테스트 예제도 함께 제공해 드리겠습니다.
#
#
# 리뷰 4:
# --------------------------------------------------------------------------------
# [스타일 검사]
# 다음 코드에서 스타일 면에서 몇 가지 개선 포인트를 찾았습니다. 핵심은 네이밍의 일관성, 불필요한 네이밍 충돌 회피, 주석/문서화, 그리고 파이썬식 코딩 습관 적용입니다.
#
# 1) 네이밍 컨벤션
# - 문제점
#   - 함수명과 변수명은 snake_case를 잘 따르고 있지만, 파라미터 이름으로 built-in 이름인 list를 사용하고 있습니다. 이는 가독성과 버그 위험을 높입니다.
#   - 클래스 명이 userManager로, 파팅 CamelCase(Pep8) 규칙에 어긋납니다. 클래스는 UserManager처럼 대문자 단어 조합으로 표기하는 것이 일반적입니다.
#   - 데이터 구조로 사전을 사용하는 부분은 좋지만, 더 구조화된 타입을 쓰는 것을 고려할 수 있습니다.
# - 개선 제안
#   - 파라미터 이름은 items, values 등으로 변경.
#   - 클래스 이름은 UserManager로 변경.
#   - 가능하면 User라는 데이터 클래스를 만들어 사용하는 방식으로 일관성 강화.
# - 예시
#   - find_duplicates 함수의 파라미터를 list 대신 items로 변경(Base: 내부에서 아이템에 접근하므로 일반명 사용).
#
# 2) 코드 포맷팅
# - 문제점
#   - top-level 함수/클래스 정의 사이에 공백 줄은 PEP 8상 "두 개의 빈 줄"을 권장합니다. 현재는 하나만 보일 수 있어 두 줄로 늘리는 것이 좋습니다.
#   - 주석/문서화가 없어 가독성과 의도 파악이 어렵습니다.
# - 개선 제안
#   - 두 개의 빈 줄로 구분
#   - 각 함수/클래스에 간단한 docstring 추가
#   - 가능하면 타입 힌트 추가
# - 예시
#   - def find_duplicates(items): ... 다음 함수 정의 사이에 두 줄 공백
#
# 3) 주석 및 문서화
# - 문제점
#   - 코드에 docstring나 설명이 없습니다.
# - 개선 제안
#   - 각 함수에 기능 설명, 입력/출력의 기대를 명시하는 docstring 추가.
#   - 클래스에도 역할에 대한 간단한 설명 추가.
#
# 4) 코드 일관성 및 베스트 프랙티스
# - 문제점
#   - sum이라는 변수명을 사용해 내장 함수(sum)를 숨기는 상황이 있습니다.
#   - 비어 있는 입력에 대한 예외 처리나 반환 방식이 불명확합니다(calculate_average에서 빈 입력 처리 필요 가능성).
#   - 데이터 구조를 dict로 계속 사용하면 타입 안정성이 떨어질 수 있습니다.
# - 개선 제안
#   - sum 대신 total 같은 로컬 변수명 사용 자제 및 sum 빌트인 함수 사용
#   - calculate_average에서 빈 입력 처리(예: 예외를 던지거나 안전한 기본값 반환) 결정
#   - 가능하면 dataclass를 도입해 User를 명확히 표현
# - 예시
#   - calculate_average에서 sum 대신 built-in sum 사용, 비어 있는 숫자 목록에 대한 처리 추가
#
# 5) 구체적인 개선안(실전 예시)
# 아래는 위 개선점을 반영한 예시 코드입니다. 참고용으로, 원래 의도에 따라 적절히 응용하세요.
#
# - find_duplicates(items) 개선 예시
#   - 문제: 파라미터 이름이 list로 충돌 가능, 알고리즘 O(n^2)이고 주석 없음
#   - 개선안:
#     - 파라미터명을 items로 변경
#     - 간단한 중복 추출 로ジック 도입(집합 사용 가능 시)
#     - 두 줄 공백 및 docstring 추가
#
#   개선 예시:
#   def find_duplicates(items):
#       """Return a list of items that appear more than once in 'items'.
#       Each duplicate is included only once in the result.
#       Note: items의 원소가 해시 가능할 때만 세트 사용이 안전합니다.
#       """
#       seen = set()
#       duplicates = []
#       for item in items:
#           if item in seen:
#               if item not in duplicates:
#                   duplicates.append(item)
#           else:
#               seen.add(item)
#       return duplicates
#
# - calculate_average(numbers) 개선 예시
#   - 문제: sum 변수로 built-in을 숨김, 비어있을 때 처리 미흡
#   - 개선안:
#     - sum 빌트인 사용
#     - 비어있을 때의 동작 정의(예외 또는 기본값)
#     - docstring 추가
#
#   개선 예시(예외를 던지는 방식):
#   def calculate_average(numbers):
#       """Return the arithmetic mean of numbers.
#       Raises ValueError if 'numbers' is empty.
#       """
#       if not numbers:
#           raise ValueError("numbers must not be empty")
#       return sum(numbers) / len(numbers)
#
# - UserManager 클래스 개선 예시
#   - 문제: 클래스 이름이 userManager, 데이터 저장 구조가 dict
#   - 개선안:
#     - 클래스명을 UserManager로 변경
#     - 데이터 모델을 dataclass로 도입
#     - 타입 힌트 및 간단한 주석 추가
#
#   개선 예시:
#   from dataclasses import dataclass
#   from typing import List, Optional
#
#   @dataclass
#   class User:
#       name: str
#       age: int
#
#   class UserManager:
#       """Manage a list of User objects."""
#       def __init__(self) -> None:
#           self.users: List[User] = []
#
#       def add_user(self, name: str, age: int) -> None:
#           self.users.append(User(name=name, age=age))
#
#       def get_user(self, name: str) -> Optional[User]:
#           for user in self.users:
#               if user.name == name:
#                   return user
#           return None
#
# - 선택적 추가 제안
#   - 예외적이지만, 데이터 모델을 더 확고하게 하려면 get_user에서 이름이 고유하다고 가정하지 말고, 중복 시점 처리나 raise를 고려할 수 있습니다.
#   - 필요 시 __repr__를 dataclass에 자동으로 만들어지는 기본 표현으로 충분히 사용할 수 있습니다.
#
# 정리
# - 네이밍: built-in 이름 오버라이딩 가능성 제거, 클래스명은 CamelCase 적용, 데이터를 표현하는 구조는 데이터 클래스 도입 고려.
# - 포맷팅: 두 줄 간격, docstring 추가, 타입 힌트 활성화.
# - 주석: 함수/클래스에 간단한 설명 추가.
# - 베스트 프랙티스: 파이썬스러운 구현(예: sum 사용, 가급적 간단한 루프/집합 활용), 빈 입력 처리 고려.
# - 일관성: snake_case를 함수/메서드에 유지하고, 클래스는 CamelCase로 통일.
#
# 필요하시면 위 개선안을 바탕으로 원래 코드 전체를 하나의 수정된 버전으로 정리해 드리겠습니다. 또한, dataclass 도입 여부나 예외 처리 방식(0으로 반환 vs 예외 발생) 등 프로젝트 컨벤션에 맞춘 선택지도 함께 제안해 드릴 수 있습니다.

# %% [markdown]
# ### 통합 리포트 확인

# %%
print(result["final_report"])
# Out:
# 종합 최종 리포트
#
# 목적
# - 현재 코드베이스의 주요 문제점을 식별하고, 실행 가능한 개선 방향과 우선순위를 제시합니다.
# - find_duplicates, calculate_average, UserManager(class명은 UserManager로 수정 제안) 구조를 중심으로, 성능/안정성/가독성을 함께 개선하기 위한 구체적 액션 아이템을 제공합니다.
# - 향후 모듈화/테스트 전략까지 포함한 실무 가이드라인을 제공합니다.
#
# 1) 주요 발견 사항 요약
# - 네이밍 및 가독성
#   - find_duplicates의 매개변수 이름이 Python 내장 타입 이름인 list를 그림자화하고 있음. 가독성과 유지보수에 악영향.
#   - class name이 userManager로 되어 있어 PEP8(그리고 일반적 관례)와 어긋남. UserManager 권장.
# - 입력 검증 및 예외 처리의 부재
#   - find_duplicates는 None 입력에 대한 방어가 없어 TypeError가 발생할 수 있음.
#   - calculate_average는 비어있는 입력에서 0으로 나누는 상황 위험. None/비숫자형 입력에 대한 검증 부재.
# - 성능 및 알고리즘 설계
#   - find_duplicates가 이중 루프(O(n^2))로 구현되어 대규모 입력에서 비효율적.
#   - NaN 처리 옵션이 부재. NaN을 중복으로 간주하려면 별도 처리 필요.
# - 데이터 모델링 및 데이터 접근성
#   - userManager가 내부 상태를 직접 노출하는 get_user를 제공. 외부에서 반환된 객체를 수정하면 내부 무결성 위험이 있음.
#   - 입력 검증(이름/나이 타입) 및 스레드 안전성에 대한 고려가 미흡.
# - 모듈화 및 테스트 준비 미흡
#   - 현재 구조는 하나의 파일에 세 가지 기능이 모여 있고, 타입 힌트/문서화가 부족. 단위 테스트 및 재사용성/확장성 측면에서 한계가 있음.
#
# 2) 개선 우선순위 (개선의 필요성에 따른 분류)
# - Critical (즉시 조치 권장)
#   - None 입력에 대한 방어 및 예외 처리 일관화: 모든 외부 입력에 대해 명확한 예외 또는 검증 경로를 두기.
#   - find_duplicates의 매개변수 이름 변경 및 빌트인과의 충돌 방지.
#   - calculate_average의 내장 sum 그림자화 제거 및 빈 입력 처리 방식 확정.
# - High (성능 및 안정성 향상)
#   - find_duplicates의 시간복잡도 개선: 해시 기반 방식으로 O(n) 도달 또는 순서를 보존하는 방식으로 구현. NaN 처리 옵션은 선택적으로 두기.
#   - UserManager의 접근 안전성 강화: get_user가 내부 상태를 얕은 복사본으로 반환하도록 수정(또는 저장소 레이어 분리).
# - Medium (가독성/유지보수성 강화)
#   - 전반적인 타입 힌트 추가, docstring 도입, PEP8 준수(네이밍, 포맷, 공백 규칙).
#   - 모듈화 구조 도입 제안(모델, 저장소, 유틸리티, 서비스 분리) 및 간단한 테스트베이스 마련.
# - Low (추가적 품질 개선)
#   - NaN 특수 케이스에 대한 정책 확정(필요 시 옵션 플래그 추가).
#   - 로깅/관측성 제거 또는 강화(버그 트래킹 용도).
#
# 3) 전체적인 코드 품질 평가
# - 강점
#   - 기능 단위로의 고립은 되어 있어 단일 책임 원칙에 부합하는 부분이 있음.
#   - 간단한 샘플 구조로 실습/학습 목적에 적합.
# - 약점
#   - 스타일/네이밍 통일성 부족으로 인해 협업 시 혼동 가능.
#   - 예외 처리/타입 안전성 부재로 인해 런타임 에러 위험 증가.
#   - 내부 상태를 외부에 노출하는 get_user 등의 설계로 데이터 무결성 문제가 생길 수 있음.
#   - 성능 측면에서 find_duplicates가 O(n^2)로 비효율적.
#   - 모듈화가 부족하여 대규모 시스템 확장 시 유지보수 비용 증가 가능.
# - 개선하면 얻을 이점
#   - 가독성/일관성 증가, 예외/타입 안전성 강화로 버그 감소.
#   - 성능 개선으로 대규모 입력에서도 안정적인 응답 시간 확보.
#   - 데이터 모델링 도입으로 유지보수성과 확장성 증가.
#
# 4) 구체적인 액션 아이템(실행 순서 제안)
# A. 공통 기초 개선
# - [A1] 매개변수와 변수명 정리
#   - find_duplicates의 매개변수명을 items로 변경하고, 내부 구현에서 items에 접근하도록 수정.
#   - calculate_average에서 sum이라는 로컬 변수 이름을 피하고 내장 sum을 직접 사용하는 방식으로 남기더라도 그림자화 방지.
# - [A2] None/빈 입력에 대한 명시적 검사 도입
#   - find_duplicates: items가 None이면 TypeError를 명시적으로 발생시키고, 비정상 입력에 대한 안전장치 추가.
#   - calculate_average: 숫자 시퀀스가 비어있을 때 ValueError를 발생시키는 방식 또는 합리적 기본값 정책 수립.
# - [A3] docstring/타입 힌트 추가
#   - 모든 함수에 간단한 설명, 입력/출력 타입의 docstring 추가.
#   - 각 클래스에도 역할과 사용법에 대한 간단한 설명 추가.
# - [A4] 데이터 타입 안전성 강화
#   - 가능한 경우 입력 데이터에 대한 타입 체크를 추가하고, 비숫자형 타입의 경우 예외로 처리.
#
# B. 성능 및 알고리즘 개선
# - [B1] find_duplicates의 성능 개선
#   - 해시 기반 접근으로 O(n) 시간에 중복 추출 가능하도록 구현(또는 순서를 보존하는 버전 병행 필요 시 2패턴 구현).
#   - 제안 버전 예시(요약): 해시맡을 사용해 등장 여부를 추적하고, 중복으로 확정된 값만 최종 결과에 한 번만 담도록 구현. 입력 순서를 최대한 보존하는 버전은 두 단계로 처리.
# - [B2] NaN 처리 옵션
#   - 필요 시 NaN을 중복으로 간주할지 여부를 옵션으로 두고, 기본 동작은 호환성 있게 유지.
# - [B3] calculate_average 성능 및 안정성
#   - 가능하면 내장 sum을 사용하고, 입력이 제너레이터/이터레이터일 때도 안전하게 동작하도록 제너레이터 친화형 구현 고려.
#   - 빈 입력 처리 정책 확정(에러/0 반환 중 하나를 팀 합의로 결정).
#
# C. 데이터 모델링 및 저장소 계층 도입
# - [C1] User 데이터 모델 도입
#   - dataclass 기반의 User 모델 도입 권장: name: str, age: int 등.
# - [C2] UserManager 재구성
#   - 내부 저장 구조를 dict[str, User]로 바꾸어 빠른 조회를 가능하게 하되, get_user는 얕은 복사본을 반환하거나 저장소를 분리하여 무결성 유지.
#   - 중복 이름 정책에 대한 명확한 정의 필요(중복 허용 여부에 따라 구현 방식 선택).
# - [C3] 모듈화 제안
#   - models.py: User 데이터 모델
#   - repositories.py: InMemoryUserRepository 같은 저장소 구현
#   - utils.py: find_duplicates, calculate_average 등 일반 유틸
#   - services.py: UserManager 같은 도메인 로직
#   - tests/ 폴더 구성 및 단위 테스트 작성
#
# D. 품질 관리 도구 도입
# - [D1] 타입 검사 도구 도입(mypy 등)
# - [D2] 린트/포맷 도구(ruff/flake8, Black) 적용
# - [D3] CI에 기본 테스트 러너 및 정적 분석 포함
#
# E. 테스트 전략
# - [E1] 단위 테스트 추가
#   - find_duplicates: 다양한 입력(정수/문자열, 중복 다수, None/빈 입력, 해시 불가능한 타입 포함 가능 여부) 테스트
#   - calculate_average: 빈 입력, None 입력, 음수/양수, 제너레이터 입력
#   - UserManager: add_user/ get_user 동작 확인(복사본 반환 여부, 입력 검증 실패 시 예외, 중복 정책에 따른 동작)
# - [E2] 경계 조건 테스트
#   - NaN 처리 옵션이 활성화되었을 때의 동작 여부 테스트
#   - 동시성/스레드 안전성은 간단한 시나리오로도 점검 계획 수립
#
# F. 점진적 마이그레이션 계획
# - [F1] 파일 하나의 점진적 리팩토링으로 시작하되, 모듈 구조를 점차 도입
# - [F2] 데이터 모델링 도입 시 backward compatibility를 고려한 어댑터 계층(Optional)
# - [F3] 중요 로직(find_duplicates, calculate_average)부터 테스트 커버를 먼저 확충하고 점진적 교체
#
# 5) 실무적으로 적용할 구체적 수정 방향(요약)
# - find_duplicates
#   - 매개변수 이름을 items로 변경하고 None 체크 추가.
#   - 해시 기반 중복 탐지로 성능 개선(O(n)), 순서를 보존하는 버전은 추가 로직으로 구현.
#   - NaN/특수 값 처리 옵션 도입 여부를 결정하고, 기본 동작은 기존보다 안전한 방식으로 유지.
# - calculate_average
#   - sum이 로컬 변수로 그림자지지 않도록 코드 정리(필요 시 내장 sum 사용).
#   - 입력이 비어있거나 None일 때 명확한 예외를 발생시키거나 특정 기본값을 반환하도록 정책 확정.
#   - 제네레이터/이터레이터 입력에도 안정적으로 동작하도록 구현.
# - UserManager
#   - 클래스 이름을 UserManager로 변경.
#   - User 데이터 모델 도입(데이터클래스 사용 권장).
#   - 내부 저장 구조를 dict[str, User] 또는 List[User] + 인덱스 맵으로 설계하되, get_user의 반환값이 내부 상태를 직접 수정하지 못하도록 얕은 복사본 반환 또는 저장소 분리 구현.
#   - 입력 검증 추가(name: str, age: int 등) 및 예외 정책 명시.
#   - 필요 시 추가 기능(리스트 조회, 삭제, 업데이트 등) 고려.
# - 전반적 품질 관리
#   - 타입 힌트, docstring, 예외 처리 강화.
#   - 두 줄 공백, 일관된 네이밍(Pep8) 준수.
#   - 모듈화 구조 도입 시 모델/저장소/유틸/서비스 계층 분리.
#   - 테스트 커버리지 확충 및 CI/CD 파이프라인 구성.
#
# 6) 실행 가능한 다음 단계 제안
# - 1주차
#   - Critical 개선 먼저: find_duplicates/items None 체크, calculate_average 빈 입력 처리 정책 확정.
#   - 간단한 유닛 테스트 추가.
# - 2주차
#   - find_duplicates의 해시 기반 구현 도입(가능하면 순서를 보존하는 버전도 함께).
#   - calculate_average를 내장 sum 버전으로 간단히 교체하고, 제너레이터 입력까지 호환되도록 보완.
#   - UserManager의 네이밍 및 기본 구조를 개선하되, 데이터 모델 도입의 골격을 마련.
# - 3주차
#   - 데이터 모델링(dataclass)과 저장소 계층 도입(모듈화 시작).
#   - 전체에 대한 타입 체킹(mypy) 및 린트 도구 도입.
#   - 테스트 커버리지 확대 및 간단한 로깅 추가.
#
# 부록: 권장 수정 예시(요약)
# - find_duplicates 개선 방향
#   - 매개변수명을 items로 변경하고 None 체크 추가.
#   - 해시 기반으로 중복을 빠르게 탐지하되, 필요 시 순서를 보존하는 버전 병행.
# - calculate_average 개선 방향
#   - 입력이 비어있으면 ValueError를 던지거나 명시적 처리.
#   - 내장 sum 사용 여부를 결정하고, 제너레이터 입력에서도 안전하게 동작하도록 구성.
# - UserManager 개선 방향
#   - 클래스명을 UserManager로 변경.
#   - User 데이터 모델 도입(dataclass).
#   - 저장소를 dict[str, User]로 구성하여 get_user의 평균 O(1) 조회 구현 가능.
#   - 입력 검증 추가(name/age), 얕은 복사 반환 등 데이터 무결성 확보.
#
# 마무리
# - 본 최종 리포트는 현재 코드를 학습용 수준에서 실무 개발로 전환하는 데 필요한 방향성을 제시합니다. 제시된 개선점의 우선순위에 따라 단계적으로 적용하면 가독성, 안정성, 성능, 확장성이 크게 향상될 것입니다.
# - 필요하시면 위의 개선안을 바탕으로 실제 수정된 코드 샘플과 테스트 코드 전체를 함께 제공해 드리겠습니다. 또한 팀의 코딩 스타일(예: 합의된 예외 정책, 로깅 정책)에 맞춘 최종 패치 세트도 함께 작성해 드립니다.

# %% [markdown]
# ### [Langsmith](https://smith.langchain.com/)

# %% [markdown]
# ![image.png](attachment:image.png)
